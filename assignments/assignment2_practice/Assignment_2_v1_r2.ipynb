# %% [markdown]
# # Assignment 2 - CT5120
#
# ### Instructions:
# - Complete all the tasks below and upload your submission as a Python notebook on Blackboard with the filename “`StudentID_Lastname.ipynb`” before **23:59** on **November 25, 2022**.
# - This is an individual assignment, you **must not** work with other students to complete this assessment.
# - The assignment is worth $50$ marks and constitutes 19% of the final grade. The breakdown of the marking scheme for each task is as follows:
#
# | Task | Marks for write-up | Marks for code | Total Marks |
# | :--- | :----------------- | :------------- | :---------- |
# | 1    |                  5 |              5 |          10 |
# | 2    |                  - |             10 |          10 |
# | 3    |                  5 |              5 |          10 |
# | 4    |                  5 |              5 |          10 |
# | 5    |                  5 |              5 |          10 |

# %% [markdown]
# ---
#
# This assignment involves tasks for feature engineering, training and evaluating a classifier for suggestion detection. You will work with the data from SemEval-2019 Task 9 subtask A to classify whether a piece of text contains a suggestion or not.
#
#
# Download train.csv, test_seen.csv and test_unseen.csv from the [Github](https://github.com/sharduls007/Assignment_2_CT5120) or uncomment the code cell below to get the data as a comma-separated values (CSV) file. The CSV file contains a header row followed by 5,440 rows in train.csv and 1,360 rows in test_seen.csv spread across 3 columns of data. Each row of data contains a unique id, a piece of text and a label assigned by an annotator. A label of $1$ indicates that the given text contains a suggestion while a label of $0$ indicates that the text does not contain a suggestion.
#
# You can find more details about the dataset in Sections 1, 2, 3 and 4 of [SemEval-2019 Task 9: Suggestion Mining from Online Reviews and Forums
# ](https://aclanthology.org/S19-2151/).
#
# We will be using test_seen.csv for benchmarking our model, hence it has label. On the other hand, test_unseen is used for [Kaggle](https://www.kaggle.com/competitions/nlp2022ct5120suggestionmining/overview) competition.

# %%
# !curl "https://raw.githubusercontent.com/sharduls007/Assignment_2_CT5120/master/train.csv" > train.csv
# !curl "https://raw.githubusercontent.com/sharduls007/Assignment_2_CT5120/master/test_seen.csv" > test.csv
# !curl "https://raw.githubusercontent.com/sharduls007/Assignment_2_CT5120/master/test_unseen.csv" > test_unseen.csv

# %%
import numpy as np
import pandas as pd

# Read the CSV file.
train_df = pd.read_csv('train.csv', 
                 names=['id', 'text', 'label'], header=0)

test_df = pd.read_csv('test.csv', 
                 names=['id', 'text', 'label'], header=0)

# Store the data as a list of tuples where the first item is the text
# and the second item is the label.
train_texts, train_labels = train_df["text"].to_list(), train_df["label"].to_list() 
test_texts, test_labels = test_df["text"].to_list(), test_df["label"].to_list() 

# Check that training set and test set are of the right size.
assert len(test_texts) == len(test_labels) == 1360
assert len(train_texts) == len(train_labels) == 5440

# %% [markdown]
# ---
#
# ## Task 1: Data Pre-processing (10 Marks)
#
# Explain at least 3 steps that you will perform to preprocess the texts before training a classifier.

# %% [markdown]
# Edit this cell to write your answer below the line in no more than 300 words.
#
# ---
#
# > Check if there is any missing value.
#
# > Remove the stop words. Remove function words which are less imformative about the text. We can safely remove them without lossing any valuable information.
#
# > Remove the punctuations.
#
# > Lowercase the text. It is one of the most common preprocessing steps where the text is converted into the same case preferably lower case.
#
# > Stemming. Stemming is a simplified analysis of word structure by removing endings/beginnings of words - leaving a common stem. There are many algorithms to perform stemming, with PorterStemmer being one of the most widely used. Run the following cell to see the output from the stemmer for the sentence defined above.
#
# > Lemmatization. Lemmatisation is the linguistic analysis of word structure by a transformation of morphologically related words to a common lemma.
# Lemmatization is more complex than stemming as it depends on correctly identifying part of speech and meaning of a word in a sentence. Run the following cell to see the output from the WordNetLemmatizer.
#
# ---

# %% [markdown]
# In the code cell below, write an implementation of the steps you defined above. You are free to use a library such as `nltk` or `sklearn` for this task.

# %%
from nltk.corpus import stopwords
from string import punctuation
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

def data_preprocessing(df):
    
    # Check if there is any missing value.
    print(f"Are there missing value? {df.isnull().any()}")
    
    # remove stopwords
    stops = set(stopwords.words('english')) # store the english stop words
    df['preprocess'] = df['text'].apply(lambda x: ' '.join([w for w in x.split() if w not in (stops)]))
    
    # remove puncuations
    punct = punctuation + '—«»–„“‘’'
    df['preprocess'] = df['preprocess'].apply(lambda x: ' '.join([w.strip(punct) for w in x.split()]))

    # lowercase the text
    df['preprocess'] = df['preprocess'].apply(lambda x: ' '.join([w.lower() for w in x.split()]))
    
    # stemming
    stemmer = PorterStemmer()
    df["preprocess"] = df["preprocess"].apply(lambda x: ' '.join([stemmer.stem(w) for w in x.split()]))

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    df["preprocess"] = df["preprocess"].apply(lambda x: ' '.join([lemmatizer.lemmatize(w) for w in x.split()]))
    
    return df

# %%
train_preprocess_df = data_preprocessing(train_df)
test_preprocess_df = data_preprocessing(test_df)
# Out:
# Are there missing value? id       False
# text     False
# label    False
# dtype: bool
# Are there missing value? id       False
# text     False
# label    False
# dtype: bool

# %%
train_preprocess_df.head()
# Out:
#         id                                               text  label  \
# 0  train_0  "One would hope if I search for a word in the ...      0
# 1  train_1     "I would be beyond excited to get a response."      0
# 2  train_2  "Just like the user can select apps that are a...      1
# 3  train_3  "Once you create a CoreIndependentInputSource ...      0
# 4  train_4  "I Have problems with Contact class on Windows...      0
#
#                                           preprocess
# 0  one would hope i search word titl app would sh...
# 1                   i would beyond excit get respons
# 2  just like user select app allow run background...
# 3  onc creat coreindependentinputsourc touch visu...
# 4  i have problem contact class window 8.1 window...

# %%
test_preprocess_df.head()
# Out:
#       id                                               text  label  \
# 0  dev_0  "I understand why you might do this for the FR...      1
# 1  dev_1  "This is a significant bug and kind of hard to...      0
# 2  dev_2  "This leads the user to have to type AGAIN the...      0
# 3  dev_3  "Needless to say, disappointed, it appears I c...      0
# 4  dev_4  "Implementing the Auto-Upload feature in a Sil...      0
#
#                                           preprocess
# 0  i understand might free version feedli implor ...
# 1              thi signific bug kind hard believ fix
# 2            thi lead user type again whole descript
# 3  needle say disappoint appear i cannot develop ...
# 4  implement auto-upload featur silverlight 8.1 a...

# %% [markdown]
# ---
#
# ## Task 2: Feature Engineering (I) - TF-IDF as features (10 Marks)
#
# In the lectures we have seen that raw counts of words and `tf-idf` scores can be useful features for a classification task. Complete the following code cell to create a suggestion detector which uses `tf-idf` scores as features for a Naïve Bayes classifier.
#
# After applying your preprocessing steps, use the training data to train the classifier and make predictions on the test set. You **must not** use the test set for training.
#
# If everything is implemented correctly, then you should see a single floating point value between 0 and 1 at the end which denotes the accuracy of the classifier.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.naive_bayes import GaussianNB

# Calculate tf-idf scores for the words in the training set.
# ... your code goes here

count_vectorizer = CountVectorizer()
train_X = train_df["preprocess"]
X_train_counts = count_vectorizer.fit_transform(x for x in train_X)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)


# Train a Naïve Bayes classifier using the tf-idf scores for words as features.
# ... your code goes here
NB_classifier_tfidf = GaussianNB()
NB_classifier_tfidf.fit(X_train_tfidf.toarray(), train_labels)


# Predict on the test set.
predictions = []    # save your predictions on the test set into this list

# ... your code goes here
# generate the features for the test set
test_X = test_df["preprocess"]
X_test_counts = count_vectorizer.transform(x for x in test_X)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)

predictions = NB_classifier_tfidf.predict(X_test_tfidf.toarray())


#################### DO NOT EDIT BELOW THIS LINE #################


#################### DO NOT EDIT BELOW THIS LINE #################

def accuracy(labels, predictions):
    '''
    Calculate the accuracy score for a given set of predictions and labels.

    Args:
    labels (list): A list containing gold standard labels annotated as `0` and `1`.
    predictions (list): A list containing predictions annotated as `0` and `1`.

    Returns:
    float: A floating point value to score the predictions against the labels.
    '''

    assert len(labels) == len(predictions)

    correct = 0
    for label, prediction in zip(labels, predictions):
        if label == prediction:
            correct += 1 

    score = correct / len(labels)
    return score

# Calculate accuracy score for the classifier using tf-idf features.
accuracy(test_labels, predictions)
# Out:
# 0.5279411764705882

# %% [markdown]
# ---
#
# ## Task 3: Evaluation Metrics (10 marks)
#
# Why is accuracy not the best measure for evaluating a classifier? Describe an evaluation metric which might work better than accuracy for a classification task such as suggestion detection.

# %% [markdown]
# Edit this cell to write your answer below the line in no more than 150 words.
#
# ---
#
# > We formalise the accuracy as $Accuracy=\frac{correct}{len(labels)}$. It will fail when the dataset consists of unbalanced classes. For instance, in one dataset, if we have 90% data belong to class A and 10% data belong to class B. Even if the hypothesis fails to predict the data belongs to class B, the accuracy will be high as it can predict the data belong to class A. Therefore, accuracy does not the best measure for evaluating a classifier.
#
# > Confusion matrix F1 score
#
# ---

# %% [markdown]
# In the code cell below, write an implementation of the evaluation metric you defined above. Please write your own implementation from scratch.

# %%
def evaluate(labels, predictions):
    '''
    Calculate an evaluation score other than accuracy for a given set of predictions and labels.

    Args:
    labels (list): A list containing gold standard labels annotated as `0` and `1`.
    predictions (list): A list containing predictions annotated as `0` and `1`.

    Returns:
    float: A floating point value to score the predictions against the labels.
    '''

    # check that labels and predictions are of same length
    assert len(labels) == len(predictions)

    score = 0.0

    #################### EDIT BELOW THIS LINE #########################

    # your code goes here
    num_classes = len(np.unique(labels)) # Number of classes 
    c_matrix = np.zeros((num_classes, num_classes))

    for i in range(len(labels)):
        c_matrix[labels[i]][predictions[i]] += 1

    score = 2*c_matrix[0][0] / (2*c_matrix[0][0] + c_matrix[1][0] + c_matrix[0][1]) # F1 score
    
    #################### EDIT ABOVE THIS LINE #########################

    return score

# Calculate evaluation score based on the metric of your choice
# for the classifier trained in Task 2 using tf-idf features.
evaluate(test_labels, predictions)
# Out:
# 0.6085365853658536

# %% [markdown]
# ---
#
# ## Task 4: Feature Engineering (II) - Other features (10 Marks)
#
# Describe features other than those defined in Task 2 which might improve the performance of your suggestion detector. If these features require any additional pre-processing steps, then define those steps as well.

# %% [markdown]
# Edit this cell to write your answer below the line in no more than 500 words.
#
# ---
#
# > Delete this line and your write answer here
#
# > Using Word Embeddings as Features
#
# > GloVe is very similar to word2vec, but it starts off with buildings a co-occurence matrix, which makes it a hybrid model.
# GloVe is based on ratios of probabilities from the word-word co-occurrence matrix, combining the intuitions of count-based models while also capturing the linear structures used by methods like word2vec (Pennington et al. 2014)
# Here and here are good explanations of the differences between word2vec and GloVe in more detail.
# The GloVe embedding model was proposed by the Stanford NLP group in 2014. Here is the article and the website for the project.
#
# > Tokenization. Tokenization is the process of dividing a text into smaller units i.e. tokens.
# nltk provides a word_tokenize function to tokenize a sentence in a given language.
#
# > mean pooling
#
# ---

# %% [markdown]
# In the code cell below, write an implementation of the features (and any additional pre-preprocessing steps) you defined above. You are free to use a library such as `nltk` or `sklearn` for this task.
#
# After creating your features, use the training data to train a Naïve Bayes classifier and use the test set to evaluate its performance using the metric defined in Task 3. You **must not** use the test set for training.
#
# To make sure that your code doesn't take too long to run or use too much memory, you can consider a time limit of 3 minutes and a memory limit of 12GB for this task.

# %%
# Create your features.
# ... your code goes here
import gensim.downloader as api
glove = api.load('glove-wiki-gigaword-300')

# Tokenization
train_tokens = [word_tokenize(sent) for sent in train_df["preprocess"]]
test_tokens = [word_tokenize(sent) for sent in test_df["preprocess"]]

def word_embedding_mean_pooling(tokens): # extract the word embeddings for each word in the input
    all_pooled_vecs = []
    
    oov = np.random.rand(1,300) # random vector to represent out-of-vocab

    for toks in train_tokens:
        text_vecs = []

        for tok in toks:
            if tok in glove:
                mean_pool = np.mean(np.vstack(glove[tok]), axis=0)
                all_pooled_vecs.append(mean_pool)
            else:
                mean_pool = np.mean(np.vstack(oov), axis=0)
                all_pooled_vecs.append(mean_pool)

    #df["embeddings"] = all_pooled_vecs
    
    return all_pooled_vecs


# Train a Naïve Bayes classifier using the features you defined.
# ... your code goes here
# NB_classifier_emb = GaussianNB()
# NB_classifier_emb.fit(word_embedding_mean_pooling(train_tokens), train_labels)
# preds = NB_classifier_emb.predict(test_tokens)

# Evaluate on the test set.
# ... your code goes here

# %%
all_pooled_vecs = word_embedding_mean_pooling(train_tokens)

# %%
all_pooled_vecs
# Out:
# [array([0.00103563], dtype=float32),
#  array([0.0094115], dtype=float32),
#  array([-0.0061282], dtype=float32),
#  array([-0.00906112], dtype=float32),
#  array([-0.01427851], dtype=float32),
#  array([-0.00206503], dtype=float32),
#  array([0.49270497, 0.14408031, 0.06355362, 0.76444143, 0.99433624,
#         0.08576202, 0.19322548, 0.44464105, 0.68433327, 0.67702083,
#         0.81132807, 0.55400211, 0.55940804, 0.78777252, 0.81619395,
#         0.83072325, 0.27954726, 0.93347045, 0.73424948, 0.36948924,
#         0.07481283, 0.41160118, 0.44019642, 0.76053286, 0.1599249 ,
#         0.24214534, 0.31286122, 0.91203626, 0.48775055, 0.8540095 ,
#         0.03350024, 0.19871349, 0.2151911 , 0.86999327, 0.68897907,
#         0.58261416, 0.36533717, 0.05122495, 0.92451873, 0.50030962,
#         0.37489017, 0.18326293, 0.33774634, 0.36996481, 0.50737121,
#         0.53868618, 0.08844242, 0.5293892 , 0.58075782, 0.3735487 ,
#         0.95540235, 0.65478228, 0.25257404, 0.8104038 , 0.4497289 ,
#         0.03005141, 0.17007852, 0.56520049, 0.89633617, 0.51435281,
#         0.32217296, 0.68681822, 0.86947497, 0.24161106, 0.96808641,
#         0.29319497, 0.03942019, 0.9101028 , 0.63957785, 0.85464127,
#         0.83978535, 0.90612208, 0.76505524, 0.87221755, 0.66857547,
#         0.46021472, 0.80464207, 0.21588283, 0.36042085, 0.89980397,
#         0.41054057, 0.38097961, 0.93393215, 0.79043096, 0.90228068,
#         0.19069539, 0.37835418, 0.82160673, 0.15076425, 0.80125984,
#         0.96840027, 0.82290053, 0.59511034, 0.13849174, 0.23066814,
#         0.18449006, 0.63042084, 0.57038954, 0.08713915, 0.97494248,
#         0.73491687, 0.39057381, 0.42111344, 0.64181265, 0.20651762,
#         0.79833258, 0.6035447 , 0.59048294, 0.65876137, 0.18244491,
#         0.69061022, 0.73150239, 0.7577983 , 0.74036719, 0.56961511,
#         0.16215441, 0.75760209, 0.80529412, 0.53969912, 0.16944016,
#         0.14149463, 0.19993844, 0.3898211 , 0.5375869 , 0.27566107,
#         0.85683432, 0.2775644 , 0.74273347, 0.47134259, 0.84798174,
#         0.99460252, 0.56900871, 0.53377611, 0.4555392 , 0.13056474,
#         0.48134274, 0.93102168, 0.24661057, 0.45567373, 0.25978684,
#         0.3448372 , 0.82915839, 0.06978108, 0.5658778 , 0.4389483 ,
#         0.26294147, 0.61787927, 0.76452274, 0.266833  , 0.17057539,
#         0.38963612, 0.78531228, 0.28032013, 0.85417433, 0.55559796,
#         0.32013923, 0.76113444, 0.43999788, 0.56436538, 0.2092625 ,
#         0.6256254 , 0.59592019, 0.8452881 , 0.08385048, 0.73295598,
#         0.92691009, 0.56966032, 0.28144217, 0.44388037, 0.71581664,
#         0.92654693, 0.58255608, 0.5703818 , 0.0515875 , 0.75057876,
#         0.99220452, 0.87450936, 0.37807886, 0.58517597, 0.80937639]),
#  array([-0.01382789], dtype=float32),
#  array([0.00198496], dtype=float32),
#  array([0.0173924], dtype=float32),
#  array([-0.00958641], dtype=float32),
#  ...]

# %%
train_tokens
# Out:
# [['one',
#   'would',
#   'hope',
#   'i',
#   'search',
#   'word',
#   'titl',
#   'app',
#   'would',
#   'show',
#   'search'],
#  ['i', 'would', 'beyond', 'excit', 'get', 'respons'],
#  ['just',
#   'like',
#   'user',
#   'select',
#   'app',
#   'allow',
#   'run',
#   'background',
#   'would',
#   'great',
#   'could',
#   'select',
#   'app',
#   'allow',
#   'chang',
#   'phone',
#   'set'],
#  ['onc',
#   'creat',
#   'coreindependentinputsourc',
#   'touch',
#   'visual',
#   'feedback',
#   'visibl',
#   'again'],
#  ['i',
#   'have',
#   'problem',
#   'contact',
#   'class',
#   'window',
#   '8.1',
#   'windowsphon',
#   '8.1',
#   'with',
#   'code',
#   'var',
#   'p',
#   'new',
#   'windows.applicationmodel.contacts.contactpick',
#   'p.desiredfieldswithcontactfieldtype.add',
#   '(',
#   'windows.applicationmodel.contacts.contactfieldtype.email',
#   'ilist',
#   '<',
#   'windows.applicationmodel.contacts.contact',
#   'contact',
#   'await',
#   'p.pickcontactsasync',
#   'contacts.count',
#   '0',
#   'foreach',
#   'windows.applicationmodel.contacts.contact',
#   'c',
#   'contact',
#   'await',
#   'new',
#   'windows.ui.popups.messagedialog',
#   '(',
#   'c.firstnam',
#   'c.lastnam',
#   'n',
#   'c.id',
#   ')',
#   '.showasync',
#   'in',
#   'window',
#   '8.1',
#   'field',
#   'lastnam',
#   'alway',
#   'empti',
#   'field',
#   'firstnam',
#   'also',
#   'contain',
#   'lastnam'],
#  ['for', 'exampl', 'show', 'notif', 'area', 'swipe', 'left', 'right'],
#  ['thi', 'power', 'control/pag', 'yet', 'look', 'good', 'eye', 'well'],
#  ['thi',
#   'allow',
#   'bulk',
#   'import',
#   'save',
#   'later',
#   'item',
#   'tool',
#   'like',
#   'pinboard.in'],
#  ['although',
#   'seem',
#   'customaudioeffect',
#   'run',
#   'worker',
#   'thread',
#   'ui',
#   'thread',
#   'seem',
#   'medium',
#   'playback',
#   'would',
#   'also',
#   'impact',
#   'ui',
#   'load',
#   'bit',
#   'heavier'],
#  ['we',
#   'alreadi',
#   'pulltorefreshlistview',
#   'toolkit',
#   'also',
#   'integr',
#   'function',
#   'control',
#   'chang',
#   'name',
#   'someth',
#   'suitabl',
#   'like',
#   'listviewex',
#   'function',
#   'singl',
#   'control'],
#  ['i',
#   "'",
#   'v',
#   'notic',
#   'paus',
#   'resum',
#   'download',
#   'acceler',
#   'updat',
#   'rate',
#   'everi',
#   '250',
#   'm'],
#  ['on', 'system', 'work', 'expect'],
#  ['so',
#   'although',
#   'in',
#   'e.g',
#   'net-bas',
#   'store',
#   'app',
#   'system.diagnostics.tracing.eventsourc',
#   'class',
#   'avail',
#   'use',
#   'gener',
#   'custom',
#   'etw',
#   'event',
#   'appear',
#   'point',
#   'moment',
#   'you',
#   'more'],
#  ['in', 'debug', 'mode', 'work', 'fine'],
#  ['but', 'old', 'wp7', 'work', 'fine', 'use', 'bt', 'soni', 'car', 'stereo'],
#  ['add',
#   'custom',
#   'calendarview',
#   'control',
#   'person',
#   'option',
#   'one',
#   'includ',
#   'sdk'],
#  ['localizationstr',
#   'har',
#   'bing',
#   'translat',
#   'api',
#   'time',
#   'download',
#   'lazi',
#   'translat',
#   'text',
#   'device',
#   "'",
#   'local',
#   'languag',
#   'save',
#   'translat',
#   'dictionari',
#   'app',
#   'futur',
#   'download',
#   'local',
#   'retriev',
#   'exist',
#   'copi',
#   'app',
#   'local'],
#  ['an', 'nativ', 'app', 'permit', 'open', 'file', 'rar', 'zip', 'format'],
#  [],
#  ['i',
#   'concern',
#   'whether',
#   'abl',
#   'opt',
#   'disabl',
#   'featur',
#   'within',
#   'app'],
#  ['27',
#   '>',
#   'c',
#   ':',
#   '\\program',
#   'file',
#   'x86',
#   ')',
#   '\\window',
#   'kits\\10\\include\\10.0.14393.0\\um\\winioctl.h',
#   '(',
#   '6513',
#   'warn',
#   'c4668',
#   'win32_winnt_win10_th2',
#   'defin',
#   'preprocessor',
#   'macro',
#   'replac',
#   '0',
#   'if/',
#   '#',
#   'elif',
#   'compil',
#   'sourc',
#   'file',
#   'src\\win10\\appinsightswin10.cpp'],
#  ['it',
#   "'",
#   'aesthet',
#   'visualfeedback',
#   'kill',
#   'perform',
#   'framer',
#   'game',
#   'drop',
#   'half',
#   'iron',
#   'think',
#   'that',
#   "'",
#   'kind',
#   'app',
#   'coreindependentinputsourc',
#   'creat',
#   'first',
#   'place'],
#  ['a',
#   'app',
#   'develop',
#   'current',
#   'stuck',
#   '2',
#   'method',
#   'gener',
#   'revenu',
#   '1',
#   'one',
#   'time',
#   'app',
#   'payment',
#   '2',
#   'ad'],
#  ['2', 'hot', 'plug', 'devic', 'unit', 'idl', '1min'],
#  ['wpf', 'app', 'work', 'much', 'better', 'ngen', "'d"],
#  ['for',
#   'larg',
#   'team',
#   'one',
#   'team',
#   'member',
#   'abl',
#   'bad',
#   'design',
#   'decis'],
#  ['basic',
#   'implement',
#   'iinternetprotocol',
#   'famili',
#   'com',
#   'interfac',
#   'window',
#   'phone',
#   '8',
#   'allow',
#   'u',
#   'add',
#   'protocol',
#   'handler',
#   'in',
#   'registri',
#   'possibl',
#   'window',
#   '8'],
#  ['we',
#   'like',
#   'number',
#   'benefit',
#   'store',
#   'offer',
#   'seem',
#   'without',
#   'way',
#   'build',
#   'list',
#   'client',
#   'independ',
#   'microsoft',
#   'or',
#   'anyon',
#   'u',
#   'matter',
#   'key'],
#  ['i',
#   "'",
#   'v',
#   'read',
#   'project',
#   'rome',
#   'possibl',
#   'creat',
#   'cross-devic',
#   'experi',
#   'https',
#   ':',
#   '//blogs.windows.com/buildingapps/2016/10/11/cross-device-experience-with-project-rom',
#   'particularli',
#   'interest',
#   'project',
#   'rome',
#   'android',
#   'sdk',
#   'https',
#   ':',
#   '//blogs.windows.com/buildingapps/2017/02/08/announcing-project-rome-android-sdk/',
#   '#',
#   'hql7ibqtugyzrufw.97'],
#  ['p',
#   'img',
#   'src=',
#   "''",
#   'http',
#   ':',
#   '//farm7.staticflickr.com/6096/7028831993_5467feca35.jpg',
#   'p',
#   '>',
#   '3'],
#  ['compact', 'overlay', 'window', 'alway', 'shown', 'right-top', 'corner'],
#  ['contrast',
#   'window',
#   'phone',
#   'world',
#   'develop',
#   'indic',
#   'trial',
#   'mode',
#   'store',
#   'manual',
#   'track',
#   'number',
#   'day',
#   'sinc',
#   'instal',
#   'whether',
#   'user',
#   'purchas',
#   'etc'],
#  ['plea',
#   'allow',
#   'api',
#   'access',
#   '3rd',
#   'parti',
#   'develop',
#   'set',
#   'ringer',
#   'volume/mute/vibr'],
#  ['15',
#   'germani',
#   'all',
#   '4',
#   'star',
#   '1',
#   'usa',
#   '1',
#   'star',
#   '4',
#   'franc',
#   '5',
#   'star',
#   'if',
#   'open',
#   'app',
#   'window',
#   'phone',
#   'store',
#   'germani',
#   'see',
#   'total',
#   'app',
#   'review',
#   'rate',
#   '15',
#   '4',
#   'star'],
#  ['i',
#   'concern',
#   'howev',
#   'microsoft',
#   'push',
#   'enough',
#   'access',
#   'success',
#   'top',
#   'sell',
#   'app',
#   'popular',
#   'iphon',
#   'android',
#   'platform',
#   'e.g'],
#  ['a', 'good', 'exampl', 'the', 'more'],
#  ['i', 'program', 'button', 'vive', 'mimic', 'finger'],
#  ['the',
#   'current',
#   'search',
#   'offic',
#   'work',
#   'titl',
#   'onenot',
#   'doc',
#   'content',
#   'use'],
#  ['the',
#   'problem',
#   'delet',
#   'file',
#   'recreat',
#   'same',
#   'filenam',
#   'creat',
#   'date',
#   'stay',
#   'same'],
#  ['i',
#   "'m",
#   'desktopbridg',
#   'app',
#   'i',
#   'tri',
#   'use',
#   'windows.applicationmodel.appinfo',
#   'null'],
#  ['4',
#   'do',
#   'styles.xaml',
#   'or',
#   'whatev',
#   'file',
#   'contain',
#   'templat',
#   'style',
#   'done',
#   '1'],
#  ['we', 'get', 'answer', 'back', 'know', 'devic', 'network'],
#  ['thi',
#   'brake',
#   'chang',
#   'sinc',
#   'old',
#   'window',
#   'phone',
#   'store',
#   'kind',
#   'limit'],
#  ['for',
#   'exampl',
#   'i',
#   'want',
#   'go',
#   'user',
#   'path',
#   'ctrl',
#   'r',
#   'enter',
#   'press',
#   'enter'],
#  ['build',
#   'email',
#   'list',
#   'forefront',
#   'small',
#   'softwar',
#   'compani',
#   'goal',
#   'year'],
#  ['would', 'like', 'chang', 'view', 'contact', 'display'],
#  ['it', 'look', 'remov', 'someth', 'folder', 'can', 'not'],
#  ['a', 'is', 'it', 'more'],
#  ['there', 'appear', 'current', 'bug', 'android', 'app', 'evernot', 'integr'],
#  ['i',
#   'would',
#   'like',
#   'abl',
#   'enabl',
#   'wp',
#   'alert',
#   'forward',
#   'xbox',
#   'one',
#   'i',
#   'near',
#   'manual',
#   'configur',
#   'it'],
#  ['for',
#   'comparison',
#   'i',
#   "'",
#   'v',
#   'test',
#   'bonjour',
#   'avahi',
#   'android',
#   "'",
#   'network',
#   'servic',
#   'discoveri',
#   'handl',
#   'case',
#   'correctli'],
#  ['2',
#   'there',
#   'option',
#   'prevent',
#   'auto',
#   'hide',
#   'get',
#   'focu',
#   'tab',
#   'button',
#   'inputpan',
#   'like',
#   'preventkeyboarddisplayonprogrammaticfocu',
#   'also',
#   'work',
#   'uwp',
#   'target',
#   'version',
#   '16299'],
#  ['plea',
#   'make',
#   'support',
#   'set',
#   'set',
#   'automationid',
#   'corewindow',
#   'messagedialog'],
#  ['skype',
#   'contact',
#   'clutter',
#   'peopl',
#   'app',
#   'way',
#   'i',
#   'found',
#   'delet',
#   'delet',
#   'desktop',
#   'reset',
#   'phone',
#   'factori',
#   'default'],
#  ['thi', 'make', 'app', 'use', 'format', 'extrem', 'hard', 'debug'],
#  ['chrome',
#   'would',
#   'gradual',
#   'get',
#   'slower',
#   'slower',
#   'a',
#   'new',
#   'develop',
#   'sinc',
#   'feedli',
#   'ask',
#   'run',
#   'always-on',
#   'tray',
#   'app'],
#  ['i', 'like', 'window', '10', 'version', '1803'],
#  ['i',
#   "'d",
#   'like',
#   'record',
#   'audio/video',
#   'file',
#   'play',
#   'audio',
#   'file',
#   'background'],
#  ['exchang', 'rate', 'u', 'low'],
#  ['i', 'seen', 'api', 'record', 'stream', 'preview', 'captur', 'video'],
#  ['i',
#   "'",
#   'v',
#   'notic',
#   'paus',
#   'resum',
#   'download',
#   'acceler',
#   'updat',
#   'rate',
#   'everi',
#   '250',
#   'm'],
#  ['a',
#   'list',
#   'r',
#   'feed',
#   'avail',
#   'public',
#   'shareabl',
#   'list',
#   'i',
#   'attach',
#   'cover',
#   'letter',
#   'let',
#   'compani',
#   'i',
#   'interview',
#   'creat',
#   'better',
#   'pictur',
#   'person'],
#  ['add', 'printercontrol', 'wpf', 'winform'],
#  ['edg',
#   'browser',
#   'v',
#   '2015',
#   'v',
#   'code',
#   'alreadi',
#   'provid',
#   'support',
#   'es6'],
#  ['protecteddata',
#   'tripl',
#   'de',
#   'product',
#   'id',
#   'windows7',
#   'microsoft.smartdevice.connect',
#   'productid',
#   'pc',
#   'protecteddata',
#   'protecteddata',
#   'o',
#   'id'],
#  ['the',
#   'event',
#   'arg',
#   'implement',
#   'correctli',
#   'contain',
#   'ad',
#   'item',
#   'right',
#   'index',
#   'all',
#   'cover',
#   'unit',
#   'test'],
#  ['i',
#   'mappolygon',
#   'fill',
#   'semitranspar',
#   'color',
#   'like',
#   'color.fromargb',
#   '(',
#   '85255255',
#   '0',
#   'color',
#   'alway',
#   'chang',
#   'zoom',
#   'map'],
#  ['plea',
#   'set',
#   'limit',
#   'go',
#   'ask',
#   'descript',
#   'make',
#   'least',
#   '100',
#   '255',
#   'charact',
#   'long'],
#  ['i', 'program', 'button', 'vive', 'mimic', 'finger'],
#  ['i',
#   'might',
#   'abl',
#   'find',
#   'option',
#   'someon',
#   'el',
#   'anyth',
#   'add',
#   'plea',
#   'comment'],
#  ['but', 'differ', 'exactli'],
#  ['thi',
#   'behavior',
#   'make',
#   'quick',
#   'health',
#   'check',
#   'submiss',
#   'nearli',
#   'imposs'],
#  ['use', 'case', 'allow', '3rd', 'parti', 'access', 'ringer', 'set'],
#  ['i',
#   'go',
#   'download',
#   'multipl',
#   'gb',
#   'i',
#   'never',
#   'use',
#   'fix',
#   'memori',
#   'leak'],
#  ['right', 'connect', 'wrong', 'account', 'i', 'one', 'buffer', 'account'],
#  ['there', 'machin', 'learn', 'sdk', 'smilar', 'appl', 'coreml'],
#  ['but',
#   'case',
#   'want',
#   'print',
#   'receipt',
#   'want',
#   'show',
#   'receipt',
#   'screen',
#   'pas',
#   'bitmap',
#   'imag',
#   'receipt',
#   'po',
#   'printer'],
#  ['plea',
#   'make',
#   'bookmark',
#   'podcast',
#   'persist',
#   'move',
#   'anoth',
#   'podcast',
#   'come',
#   'back'],
#  ['not', 'datetim', 'control', 'anyway', 'datepick', 'calenderview', 'etc'],
#  ['for',
#   'user',
#   'sensor',
#   'differ',
#   'place',
#   'way',
#   'touch',
#   'space',
#   'xyz',
#   'coordin',
#   'like'],
#  ['i', 'alway', 'use', 'disiredaccuray', 'high'],
#  ['remov', 'max', 'limit', 'zoomlevel', '1-20'],
#  ['i', 'think', '3', 'variat', 'did', 'i', 'forget', 'ani'],
#  ['i',
#   'notic',
#   'alreadi',
#   'avail',
#   'user',
#   '7.1',
#   'version',
#   'mango',
#   'i',
#   'see',
#   'method',
#   'api',
#   'scan',
#   'next',
#   'signal',
#   'or',
#   'seek',
#   'whatev',
#   'term',
#   'call'],
#  ['at',
#   'time',
#   'may',
#   'want',
#   'set',
#   'remind',
#   'let',
#   'vibrat',
#   'pocket',
#   'still',
#   'give',
#   'notif',
#   'instead',
#   'beep',
#   'loud',
#   'want',
#   'to'],
#  ['plea', 'make', 'feedli', 'widget/gadget', 'igoogl', 'or', 'equival'],
#  ['exampl',
#   'an',
#   'app',
#   'allow',
#   'user',
#   'select',
#   'time',
#   'i.e',
#   'tomorrow',
#   '10,30',
#   'am',
#   'someth'],
#  ['when', 'hololen', 'stereo', 'mode', 'show', 'frame', 'emul'],
#  ['assum', 'follow', 'xaml', 'call', 'setdesiredbound'],
#  ['plea',
#   'cant',
#   'option',
#   'wpappmanifest',
#   'file',
#   'untick',
#   'fast',
#   'resum',
#   'allow',
#   'wp8.1',
#   'app',
#   'run',
#   'fast',
#   'resum',
#   'mode',
#   'like',
#   'wp8'],
#  ['one', 'textcanva', 'display', 'edit', 'text', 'ink'],
#  ['doe', 'anyth', 'wifi', 'one', 'locat', 'sourc'],
#  ['the',
#   'createstreamedfileasync',
#   'method',
#   'sinc',
#   'window',
#   '8',
#   'delay',
#   'creation',
#   'file',
#   'data'],
#  ['i', "'m", 'use', 'fall', 'creator', 'updat', 'sure', 'behav', 'version'],
#  ['for', 'exampl', '1'],
#  ['also',
#   'allow',
#   'youtub',
#   'video',
#   'continu',
#   'play',
#   'i',
#   'scroll',
#   'rest',
#   'feed'],
#  ['microphon', 'sampl', 'frequenc', 'fix'],
#  ['either',
#   'allow',
#   'function',
#   'go',
#   'webpag',
#   'internet',
#   'browser',
#   'outsid',
#   'feedli',
#   'use',
#   'anoth',
#   'action',
#   'view',
#   'slideshow'],
#  ['i',
#   "'m",
#   'talk',
#   'integr',
#   'stream',
#   'follow',
#   'tumblr',
#   'is',
#   'read',
#   'post'],
#  ['it', 'happen', '2nd', 'big', 'wp8.1', 'updat', 'too'],
#  ['i', 'build', 'comput', 'first', 'do', 'play', "game'son", 'it'],
#  ['that',
#   'would',
#   'significantli',
#   'reduc',
#   'amount',
#   'effort',
#   'develop',
#   'go',
#   'publish',
#   'app'],
#  ['messag', 'box', 'typic', 'yes/no/cancel', 'option'],
#  ['add',
#   'imag',
#   'crop',
#   'support',
#   'cameracaptureui',
#   'mobil',
#   'devic',
#   'desktop'],
#  ['thi', 'standard', 'featur', 'platform'],
#  ['would',
#   'realli',
#   'help',
#   'findancestor',
#   'api',
#   'ad',
#   'like',
#   'silverlight',
#   '5',
#   'wpf'],
#  ['and',
#   'i',
#   '5',
#   'viewmodel',
#   'deriv',
#   'base',
#   'view',
#   'model',
#   'base',
#   'view',
#   'model',
#   'boolean',
#   'isload',
#   'properti',
#   'i',
#   'want',
#   'abl',
#   'x',
#   ':',
#   'bind',
#   'isload',
#   'properti',
#   'view'],
#  ['the',
#   'idea',
#   'instal',
#   'partial',
#   'data',
#   'applic',
#   'cloud',
#   'servic',
#   'local',
#   'devic'],
#  ['howev',
#   'batteri',
#   'power',
#   'scenario',
#   'want',
#   'manual',
#   'switch',
#   'back',
#   'forth',
#   'time'],
#  ['seem',
#   'kind',
#   'pointless',
#   'buffer',
#   'account',
#   'nor',
#   'want',
#   'one',
#   'creat',
#   'account',
#   'middleman',
#   'feedli',
#   'facebook'],
#  ['the', 'textbox', 'control', 'use', 'control', 'window', 'program'],
#  ['run',
#   'mani',
#   'time',
#   'like',
#   'creat',
#   'date',
#   'chang',
#   'first',
#   'time',
#   'ran',
#   'code'],
#  ['window',
#   'phone',
#   'amaz',
#   'medium',
#   'consumpt',
#   'devic',
#   'bring',
#   'audiobook',
#   'back',
#   'zune',
#   'fold',
#   'would',
#   'make',
#   'much',
#   'better'],
#  ['window',
#   'develop',
#   'need',
#   'api',
#   'control',
#   'tv',
#   'tuner',
#   'display',
#   'digit',
#   'medium',
#   'screen',
#   'time'],
#  ['the', 'concept', 'page', 'use', 'skip', 'take', 'easili', 'resolv', 'issu'],
#  ['make', 'it', 'possibl', 'choos', 'differ', 'sound', 'differ', 'app'],
#  ['i',
#   'want',
#   'say',
#   'well',
#   'done',
#   'microsoft',
#   'offer',
#   'good',
#   'brow',
#   'experi',
#   'wp8.1',
#   'ie11',
#   'with',
#   'ie11',
#   'abl',
#   'watch',
#   'e.g',
#   'putlock',
#   'video',
#   'interfer',
#   'ad',
#   'pop',
#   'up',
#   'on',
#   'friend',
#   'android',
#   'thing',
#   'kept',
#   'pop',
#   'say',
#   'your',
#   'phone',
#   'viru'],
#  ['support', 'windows.media.edit', 'api', 'window', '8'],
#  ['today',
#   'applic',
#   'achiev',
#   'embed',
#   'browser',
#   'control',
#   'good',
#   'expereinc',
#   'end',
#   'user'],
#  ['current',
#   'test',
#   'return',
#   'point',
#   'insid',
#   'rect',
#   'size',
#   'map.actualwidth',
#   'map.actualheight'],
#  ['we',
#   'compani',
#   'hub',
#   'app',
#   'download',
#   'mdm',
#   'enrol',
#   'hub',
#   'app',
#   'use',
#   'background',
#   'task',
#   'post',
#   'back',
#   'devic',
#   'info',
#   'locat',
#   'avail',
#   'mdm',
#   'protocol'],
#  ['i', 'recent', 'submit', 'app', 'process', 'hung', 'i', 'click', 'submit'],
#  ['open', 'window', 'explor'],
#  ['after',
#   'gdr2',
#   'updat',
#   'lumia',
#   '820',
#   '520',
#   'devic',
#   'check',
#   'devicenetworkinformation.iswifien',
#   'within',
#   'applic',
#   'return',
#   'fals',
#   'independ',
#   'actual',
#   'wifi',
#   'avail'],
#  ['thi',
#   'mean',
#   'contentdialog.showasync',
#   'wait',
#   'currently-display',
#   'contentdialog',
#   'dismiss',
#   'show',
#   'new',
#   'dialog'],
#  ['in',
#   'window',
#   'store',
#   'i',
#   'choos',
#   'trial',
#   'mode',
#   'app',
#   'pick',
#   'number',
#   'day',
#   'i',
#   'want',
#   'trial',
#   'last'],
#  ['for',
#   'exampl',
#   'i',
#   '25',
#   'convers',
#   'rate',
#   'store',
#   'page',
#   'view',
#   'download',
#   'second',
#   'bar',
#   '5',
#   'width',
#   'first',
#   'bar',
#   'should',
#   '25'],
#  ['without',
#   'that',
#   'mean',
#   'wrap',
#   'tool',
#   'launch',
#   'instal',
#   'built',
#   'app',
#   'emul'],
#  ['i', 'would', 'realli', 'thought', 'return', 'import', 'pfx'],
#  ['the',
#   'method',
#   'would',
#   'use',
#   'develop',
#   'must',
#   'deal',
#   'diacrit',
#   'multilanguag',
#   'app'],
#  ['a', 'abov'],
#  ['there',
#   'current',
#   'way',
#   'display',
#   'webview',
#   'http',
#   'web',
#   'page',
#   'invalid',
#   'certif',
#   'even',
#   'user',
#   'specif',
#   'opt-in'],
#  ['when',
#   'long-press',
#   'link',
#   'feedli',
#   'web',
#   'view',
#   'we',
#   "'",
#   'r',
#   'given',
#   'option',
#   'add',
#   'read',
#   'list',
#   'instapap',
#   'read',
#   'later',
#   'servic'],
#  ['i',
#   'suggest',
#   'make',
#   'xaml',
#   'engin',
#   'abl',
#   'use',
#   'interfac',
#   'let',
#   'transcod',
#   'convert',
#   'instanc',
#   'string'],
#  ['i', 'think', 'new', 'dev', 'center', 'great', 'step'],
#  ['street',
#   'name',
#   'rout',
#   'shown',
#   'anoth',
#   'color',
#   'move',
#   'stay',
#   'alway',
#   'center'],
#  ['thi', 'fee', 'appli', 'altern', 'payment', 'method', 'e.g'],
#  ['my', 'app', 'keep', 'get', 'reject', 'test', 'devic', 'design', 'for'],
#  ['we',
#   'use',
#   'microsoft',
#   'express',
#   'encod',
#   'live',
#   'smooth',
#   'stream',
#   'video',
#   'feed'],
#  ['window',
#   'allow',
#   'addit',
#   'user',
#   'account',
#   'ad',
#   'track',
#   'review',
#   'applic',
#   'review',
#   'process',
#   'similar',
#   'appl',
#   'android',
#   'appl',
#   'store',
#   'allow'],
#  ['i',
#   'suggest',
#   'like',
#   'done',
#   'googl',
#   'reader',
#   'watcher',
#   'http',
#   ':',
#   '//ajnasz.hu/google-reader-watch'],
#  ['the',
#   'methodnam',
#   'properti',
#   'knowntypeattribut',
#   'type',
#   'objectmodel.entities.baseth',
#   'current',
#   'support'],
#  ['we',
#   'also',
#   'allow',
#   'simultan',
#   'pen',
#   'touch',
#   'add',
#   'touch',
#   'keyboard',
#   'hotkey',
#   'dock',
#   'custom',
#   'keyboard',
#   'typic',
#   'aid',
#   'draw',
#   'ink',
#   'base',
#   'applic'],
#  ['aplicativo', 'em', 'portugu__', 'e', 'bloqueio', 'de', 'chamada'],
#  ['the',
#   'app',
#   'store',
#   'current',
#   'show',
#   'consum',
#   'app',
#   'rate',
#   'review',
#   'countri',
#   'live',
#   'in'],
#  ['unfortun',
#   'scheduledtoastnotif',
#   'toastnotofc',
#   'schedul',
#   'lack',
#   'help',
#   'featur'],
#  ['plea',
#   'competit',
#   'advantag',
#   'would',
#   'like',
#   'provid',
#   'expedit',
#   'packag',
#   'app',
#   'certif',
#   'develop',
#   'want',
#   'app',
#   'publish',
#   'fast'],
#  ['i',
#   'write',
#   'lot',
#   'support',
#   'ticket',
#   'thi',
#   'one',
#   'realli',
#   'care',
#   'issu'],
#  ['it', "'", 'annoy'],
#  ['isalnum', '(', '-1', 'return', 'true', 'codepag'],
#  ['so', 'content', 'myapp', 'knownfolderdump.ex'],
#  ['nofificaion',
#   'center',
#   'move',
#   'left',
#   'meego',
#   'guy',
#   'alreadi',
#   'look',
#   'better',
#   'cleaner',
#   'would',
#   'copi',
#   'anyon',
#   'sinc',
#   'nokia',
#   'introduc',
#   'featur',
#   'bought',
#   'nokia',
#   'also',
#   'famili'],
#  ['remov',
#   'limit',
#   'inhibit',
#   'winrt',
#   'custom',
#   'compon',
#   'use',
#   'desktop',
#   'applic'],
#  ['window',
#   'phone',
#   'support',
#   'team',
#   'simpli',
#   'refus',
#   'commun',
#   'everyth',
#   'stop',
#   'there'],
#  ['reblog', 'support', 'would', 'nice', 'mostli', 'like', 'least'],
#  ['but', 'i', 'mostli', 'care', 'window', 'phone'],
#  ['if',
#   'window',
#   'phone',
#   'compet',
#   'acknowledg',
#   'big',
#   'sell',
#   'app',
#   'risk',
#   'lose',
#   'market',
#   'share',
#   'rather',
#   'gain',
#   'it'],
#  ['microsoft',
#   'support',
#   'answer',
#   'thi',
#   'i',
#   'review',
#   'account',
#   'show',
#   'app',
#   'publish',
#   'correctli'],
#  ['allow',
#   'messag',
#   'applic',
#   'join',
#   'default',
#   'messag',
#   'applic',
#   'hub',
#   'messag',
#   'full',
#   'interact'],
#  ['so',
#   'menu',
#   'display',
#   'user',
#   'move',
#   'mous',
#   'anoth',
#   'menu',
#   'without',
#   'click',
#   'first',
#   'menu',
#   'would',
#   'close',
#   'new',
#   'one',
#   'hover',
#   'would',
#   'open'],
#  ['allow', 'trust', '3rd', 'more'],
#  ['now', 'work', 'but', '...', 'th', 'header', 'more'],
#  ['i',
#   'remov',
#   'safe',
#   'area',
#   'call',
#   'setdesiredbound',
#   'i',
#   'experienc',
#   'frame',
#   'transport',
#   'control',
#   'even',
#   'use',
#   'control',
#   'somewher',
#   'within',
#   'page'],
#  ['user', 'ask', 'frequent', 'xbox', 'version', 'app'],
#  ['i',
#   'know',
#   'pas',
#   'string',
#   'uri',
#   'come',
#   'creat',
#   'nativ',
#   'app',
#   'web',
#   'app',
#   'limit',
#   'way',
#   'code'],
#  ['we',
#   'miss',
#   'control',
#   'like',
#   'integr',
#   'photo',
#   'viewer',
#   'show',
#   'photo',
#   'control',
#   'page',
#   'page',
#   'use',
#   'flick',
#   'gestur'],
#  ['recent', 'sego', 'mdl2', 'asset', 'mani', 'new', 'glyph'],
#  ['thi',
#   'make',
#   'hard',
#   'know',
#   'upfront',
#   'user',
#   'actual',
#   'launch',
#   'uri',
#   'xbox',
#   'total',
#   'unclear',
#   'whether',
#   'xbox',
#   'current',
#   'run',
#   'applic',
#   'allow',
#   'run',
#   'remot'],
#  ['add', 'option', 'remov', 'imag', 'contact'],
#  ['when',
#   'cortana',
#   'express',
#   'understand',
#   'base',
#   'avail',
#   'express',
#   'regist',
#   'cortana',
#   'recogn',
#   'app',
#   'name',
#   'would',
#   'great',
#   'user',
#   "'",
#   'express',
#   'fed',
#   'app',
#   'account',
#   'store',
#   'develop',
#   'review',
#   'consid',
#   'support',
#   'futur'],
#  ['the', 'visual', 'feedback', 'disabl'],
#  ['exampl', 'page', 'app1', 'configur', 'use', 'dark', 'theme'],
#  ['the', 'problem', 'appear', 'xna', 'audiosink', 'record', 'approach'],
#  ['plea',
#   'add',
#   'recent',
#   'place',
#   'suggestedstartloc',
#   'fileopenpick',
#   'api'],
#  ['we',
#   'need',
#   'way',
#   'applic',
#   'regist',
#   'type',
#   'content',
#   'handl',
#   'user',
#   'download',
#   'content',
#   'use',
#   'ie',
#   'choos',
#   'instal',
#   'applic',
#   'open',
#   'with'],
#  ['a',
#   'abil',
#   'emul',
#   'emul',
#   'bad',
#   'data',
#   'connect',
#   'discov',
#   'perform',
#   'problem',
#   'client',
#   'receiv',
#   'it'],
#  ['thi',
#   'scenario',
#   'describ',
#   'post',
#   'https',
#   ':',
#   '//www.thomasclaudiushuber.com/2017/03/10/building-a-classic-tabbed-and-databound-desktop-app-with-uwp'],
#  ['for',
#   'exampl',
#   'want',
#   'feed',
#   'everi',
#   'tumblr',
#   'feed',
#   'contain',
#   'hashtag',
#   'retail',
#   'design',
#   'http',
#   ':',
#   '//www.tumblr.com/tagged/retail+design',
#   'would',
#   'feedli',
#   'feed'],
#  ['emul', 'even', 'slower', 'wp7.1', 'one', 'process', 'realli', 'long'],
#  ['it',
#   'happen',
#   'type',
#   'play',
#   'game',
#   'slight',
#   'touch',
#   'either',
#   'back',
#   'search',
#   'button',
#   'take',
#   'context'],
#  ['the', 'restrict', 'calendar', 'edit/delet', 'redicul'],
#  ['i',
#   'alreadi',
#   'know',
#   'workaround',
#   'use',
#   'bind',
#   'practic',
#   'need',
#   'code',
#   'semant',
#   'incorrect',
#   'a',
#   'bind',
#   'transcoding/convers',
#   'differ',
#   'natur'],
#  ['it', 'get', 'number', 'linker', 'problem', 'caus', 'microsoft', 'compon'],
#  ['look', 'up'],
#  ['much',
#   'effort',
#   'made',
#   'wpf',
#   'xaml',
#   'serial',
#   'decoupl',
#   'present',
#   'assembl',
#   'move',
#   'assembl',
#   'system.xaml',
#   'system.windows.markup',
#   'thi',
#   'xaml',
#   'system',
#   'serialization/deseri',
#   'mechan',
#   'xamlservic',
#   'class',
#   'furthermor',
#   'xaml',
#   'system',
#   'power',
#   'component/concept',
#   'conspicu',
#   'absent',
#   'winrt',
#   'markup',
#   'extens'],
#  ['it',
#   'nice',
#   'window',
#   'phone',
#   'microsoft',
#   'devic',
#   'onebook',
#   'applic',
#   'read',
#   'ebook',
#   'magazin',
#   'etc'],
#  ['the', 'm', 'edg', 'incompat', 'ltsb', 'system'],
#  ['remov', 'x', ':', 'name', 'renam', 'element', 'enough', 'margin', 'gone'],
#  ['build', 'wcf', 'allow', 'on-phon', 'app-to-app', 'commun'],
#  ['i',
#   'want',
#   'sound',
#   'enabl',
#   'keyboard',
#   'highest',
#   'level',
#   'also',
#   'want',
#   'listen',
#   'radio',
#   'throuth',
#   'night',
#   'sure',
#   'next',
#   'morn',
#   'alarm',
#   'clock',
#   'sound',
#   'high',
#   'possibl',
#   'wake',
#   'up'],
#  ['if',
#   'sdk',
#   'could',
#   'run',
#   'osx',
#   'i',
#   "'d",
#   'actual',
#   'abl',
#   'creat',
#   'app',
#   'wp7'],
#  ['thi',
#   'applic',
#   'greader',
#   'pro',
#   'android',
#   'i',
#   'pull',
#   'news',
#   'normal',
#   'desktop',
#   'ticker',
#   'useless',
#   'morn',
#   'without',
#   'way',
#   'pull',
#   'feedli',
#   'or',
#   'digg',
#   'reader'],
#  ['anoth',
#   'solut',
#   'could',
#   'simpli',
#   'extend',
#   'offic',
#   'store',
#   'order',
#   'publish',
#   'vsto',
#   'add-in'],
#  ['current', 'support', 'touch', 'input'],
#  ['pc', 'app', 'harder', 'find', 'way'],
#  ['filter', 'listbox', 'import'],
#  ['there', 'option', 'hard', 'soft', 'reset'],
#  ['i',
#   'hope',
#   'idea',
#   'use',
#   'perhap',
#   'other',
#   'could',
#   'comment',
#   'whether',
#   'practic',
#   'easili',
#   'implement',
#   'not',
#   'enhanc'],
#  ['the',
#   'new',
#   'api',
#   'window',
#   '1803',
#   'creat',
#   'displaymonitor',
#   'instanc',
#   'alway',
#   'fail',
#   'error_file_not_found',
#   'except'],
#  ['the',
#   'bottom',
#   'could',
#   'quick',
#   'link',
#   'top',
#   'left',
#   'side',
#   'could',
#   'use',
#   'navig',
#   'purpos'],
#  ['i.e',
#   'feedli',
#   'handl',
#   'payment',
#   'deliveri',
#   'inform',
#   'creator',
#   'creat',
#   'inform',
#   'receiv',
#   'revenu'],
#  ['for',
#   'exampl',
#   'minimum',
#   'requir',
#   'oper',
#   'system',
#   'window',
#   '8',
#   'later',
#   'requir'],
#  ['thi',
#   'mean',
#   'applic',
#   'wish',
#   'use',
#   'capabl',
#   'backgroundag',
#   'restrict',
#   'use',
#   'local',
#   'audio',
#   'file',
#   'deploy',
#   'teh',
#   'applic',
#   'audio',
#   'stream',
#   'sourc'],
#  ['visual',
#   'studio',
#   "'",
#   'creat',
#   'packag',
#   'wizard',
#   'allow',
#   'one',
#   'assign',
#   'version',
#   'number',
#   'howev',
#   'assign',
#   'packag',
#   'version',
#   'number'],
#  ['plea', 'improv', 'app', 'submiss', 'process', 'internal/beta', 'test'],
#  ['the', 'abil', 'use', 'product', 'like', 'offic', 'vr'],
#  ['provid', 'lock', 'tile', 'tile', 'get', 'collaps', 'accident'],
#  ['it',
#   'unaccept',
#   'simpli',
#   'accord',
#   'rfc',
#   '2616',
#   'section',
#   '4.1',
#   'header',
#   'field',
#   'definit',
#   'messag',
#   'header',
#   'http',
#   '1.1',
#   'messag',
#   'valu',
#   'option'],
#  ['plea',
#   'provid',
#   'photocroptask',
#   'take',
#   'image',
#   '(',
#   'byt',
#   'provid',
#   'crop',
#   'tool'],
#  ['and', 'i', 'say', 'much', 'i', 'mean', 'much', 'more'],
#  ['hi',
#   'forc',
#   'wp8',
#   'app',
#   'upgrad',
#   'wp81',
#   'behav',
#   'differ',
#   'resum',
#   'caus',
#   'massiv',
#   'headach'],
#  ['nevertheless', 'far', 'ok', 'could', 'call', 'expect'],
#  ['the', 'user', 'function', 'within', 'select', 'app', 'more'],
#  ['there', 'keyword', 'search'],
#  ['creat', 'possibl', 'creat', 'new', 'type', 'app'],
#  ['i', 'wish', 'garbag', 'collect', 'option', 'c', 'uwp', 'app'],
#  ['right',
#   'now',
#   'i',
#   'sever',
#   'googl',
#   'app',
#   'open',
#   'separ',
#   'tab',
#   'thunderbird'],
#  ['develop',
#   'abl',
#   'creat',
#   'wp',
#   'imag',
#   'tailor',
#   'specif',
#   'state',
#   'manag',
#   'imag',
#   'snapshot'],
#  ['some',
#   'app',
#   'could',
#   'benefit',
#   'easi',
#   'way',
#   'send',
#   'toast',
#   'notif',
#   'also',
#   'maintain',
#   'notif',
#   'histori',
#   'user',
#   'could',
#   'view',
#   'afterward'],
#  ['the', 'autom', 'script', 'leav', '5', 'star', 'review', 'ask', 'app'],
#  ['it', 'would', 'also', 'good', 'track', 'caus', 'uninstal', 'spike', 'etc'],
#  ['thi',
#   'could',
#   'allow',
#   'quit',
#   'scenario',
#   'someon',
#   'current',
#   'lock',
#   'carrier',
#   'wp7',
#   'phone',
#   'avail'],
#  ['support',
#   'develop',
#   'will',
#   'get',
#   'app',
#   'convert',
#   'place',
#   'window',
#   'store',
#   'anecdot'],
#  ['local',
#   'releas',
#   'build',
#   'creat',
#   'nativ',
#   'toolchain',
#   'v',
#   '15.7.1',
#   'work'],
#  ['but',
#   'mani',
#   'desktop',
#   'applic',
#   'specif',
#   'contain',
#   'applic',
#   'manag',
#   'window',
#   'core',
#   'featur',
#   'object'],
#  ['it', 'would', 'cool', 'allow', 'applicationbar', 'icon', 'avail'],
#  ['i', "'m", 'bit', 'surpris', 'action', 'center'],
#  ['it',
#   'respons',
#   'html',
#   'element',
#   'c-head',
#   'class',
#   'font-siz',
#   'style',
#   'properti',
#   'fix',
#   '15px'],
#  ['the',
#   'trial',
#   'featur',
#   'built-in',
#   'automat',
#   'enforc',
#   'user',
#   'prompt',
#   'disabl',
#   'etc',
#   'window',
#   'store'],
#  ['want',
#   'use',
#   'list',
#   'work',
#   'autom',
#   'instal',
#   'contain',
#   'imag',
#   'there',
#   "'",
#   'check',
#   'place',
#   'block',
#   'scenario',
#   'sdk',
#   'alreadi',
#   'instal'],
#  ['like',
#   'surfac',
#   'pro',
#   'implement',
#   'pressur',
#   'layer',
#   'pen',
#   'wp8',
#   'win',
#   'rt'],
#  ['i',
#   'notic',
#   'sometim',
#   'microphon',
#   'function',
#   'iphon',
#   'android',
#   'app',
#   'tend',
#   'stall',
#   'freez'],
#  ['silverlight', 'window', 'phone', 'support', 'right', 'now'],
#  ['if',
#   'devic',
#   'connect',
#   'network',
#   'speech',
#   'recognit',
#   'local',
#   'srg',
#   'custom',
#   'grammar',
#   'behav',
#   'exactli',
#   'local',
#   'grammar',
#   'start',
#   'commun',
#   'websockets.platform.bing.com:443',
#   'endpoint',
#   'increas',
#   'ten',
#   'time',
#   'waiting-tim',
#   'result'],
#  ['like', 'mani', 'other', 'i', 'want', 'add', 'twitter', 'feed', 'r', 'feed'],
#  ['explor', 'shield', 'pictur'],
#  ['there', 'app', 'android', 'phone', 'appslock', 'app', 'window', 'phone'],
#  ['i', "'m", 'use', 'chrome', 'app'],
#  ['at',
#   'point',
#   'i',
#   'think',
#   'might',
#   'best',
#   'lift',
#   'restrict',
#   'insid',
#   'review',
#   'also',
#   'show',
#   'review',
#   'regardless',
#   'version'],
#  ['it',
#   "'",
#   'quit',
#   'frustrat',
#   'go',
#   'peopl',
#   'click',
#   'search',
#   'find',
#   'contact',
#   'dial'],
#  ['current',
#   'unavail',
#   'israel',
#   'ca',
#   "n't",
#   'compliment',
#   'alreadi',
#   'instal',
#   'offic',
#   'onedr',
#   'app'],
#  ['it', 'use', 'good', '7.8'],
#  ['use',
#   'roslyn',
#   'a',
#   'duocod',
#   'doe',
#   'uwp',
#   'applic',
#   'written',
#   'xaml',
#   'c',
#   '#',
#   '/vb.net',
#   'get',
#   'transpil',
#   'javascript',
#   'render',
#   'via',
#   'html5',
#   'canva'],
#  ['plea', 'add', 'bthproco_l2cap', 'allow', 'u', 'use', 'lower', 'implement'],
#  ['user',
#   'configur',
#   'dynam',
#   'configur',
#   'app/gam',
#   'develop',
#   'say',
#   'f1',
#   'fire',
#   'f2=reload',
#   'f7=secondari',
#   'weapon',
#   'f3=cycl',
#   'weapon',
#   'f4',
#   'touch',
#   'scroll',
#   'fingerprint',
#   'reader',
#   'it',
#   'look',
#   'ugli',
#   'lot',
#   'use',
#   'custom',
#   'devic',
#   'larg'],
#  ['that', "'", 'yall', 'need', 'hardcor', 'app'],
#  ['a',
#   'app',
#   'publish',
#   'south',
#   'africa',
#   'i',
#   'current',
#   'unabl',
#   'get',
#   'sort',
#   'proper',
#   'tax',
#   'invoic',
#   'purchas',
#   'made',
#   'develop',
#   'account'],
#  ['what', 'problem'],
#  ['plea',
#   'allow',
#   'u',
#   'maintain',
#   'app',
#   'packag',
#   'store',
#   'asset',
#   'descript',
#   'screenshot',
#   'metadata',
#   'git',
#   'repositori',
#   'simpli',
#   'push',
#   'git',
#   'remot',
#   'upload'],
#  ['uwp',
#   'safe',
#   'impract',
#   'mani',
#   'desktop',
#   'app',
#   'wpf',
#   'like',
#   'third-class',
#   'citizen',
#   'microsoft',
#   'background',
#   'cheer',
#   'upgrad',
#   'uwp'],
#  ['then', 'move', 'screen', 'problem'],
#  ['public',
#   'static',
#   'readonli',
#   'dependencyproperti',
#   'istestproperti',
#   'dependencyproperty.register',
#   '(',
#   'nameof',
#   '(',
#   'istest',
#   ')',
#   'typeof',
#   '(',
#   'bool'],
#  ['the',
#   'backgroundtask',
#   'current',
#   'launch',
#   'everi',
#   '15',
#   'minut',
#   'timetrigg'],
#  ['is', 'option', 'hope', 'near', 'futur'],
#  ['it', 'use', 'uwp', 'app', 'window', 'explor', 'realli', 'shame'],
#  ['windows___________________________________________________________________________________________________app',
#   'hub__________________________________________________________________________________________________________________________________________________________________________________________________________________î\x8f\x95',
#   'æ\x8f\x95'],
#  ['sinc',
#   'someth',
#   'like',
#   'would',
#   'pretti',
#   'much',
#   'align',
#   'whole',
#   'motion',
#   'theme',
#   'fluent',
#   'design',
#   'system',
#   'i',
#   'think',
#   'would',
#   'great',
#   'could',
#   'support',
#   'futur',
#   'build',
#   'could',
#   'use',
#   'composit',
#   'api',
#   'add',
#   'new',
#   'visual',
#   'detail',
#   'effect',
#   'app',
#   'possibl',
#   'moment'],
#  ['windbg', 'preview', 'avail', 'offlin', 'download'],
#  ['imagin',
#   'call',
#   'someon',
#   'alreadi',
#   'involv',
#   'call',
#   'wait',
#   'notif',
#   'display',
#   'avail',
#   'long',
#   'time',
#   'sever',
#   'mobil',
#   'could',
#   'give',
#   'relief',
#   'contact',
#   'later',
#   'instead',
#   'recur',
#   'call',
#   'bother',
#   'him/her'],
#  ['winrt',
#   'litter',
#   'async',
#   'getter',
#   'greatli',
#   'imped',
#   'port',
#   'code',
#   'add',
#   'unnecessari',
#   'complex',
#   'mani',
#   'case'],
#  ['i',
#   "'d",
#   'like',
#   'see',
#   'window',
#   'api',
#   "'",
#   'command',
#   'prompt',
#   'file',
#   'explor',
#   'support',
#   'much',
#   'longer',
#   'file',
#   'path'],
#  ['without',
#   'featur',
#   'definit',
#   'window',
#   'app',
#   'port',
#   'uwp',
#   'simpl',
#   'reason',
#   'we',
#   'want',
#   'write',
#   'anoth',
#   'azur',
#   'servic',
#   'handl',
#   'db',
#   'activ'],
#  ['ye', 'right', 'similar', 'her', 'movi'],
#  ['therebi', 'folderpick', 'preview', 'content', 'folder'],
#  ['forex', 'trade', 'platform', 'window', 'mobil', '8'],
#  ['when',
#   'user',
#   'start',
#   'video',
#   'playback',
#   'phone',
#   'use',
#   'suppresssystemoverlay',
#   'hide',
#   'navig',
#   'bar',
#   'on',
#   'devic',
#   'lumia',
#   '950',
#   'them',
#   'statu',
#   'bar'],
#  ['do',
#   'complain',
#   'develop',
#   'prefer',
#   'platform',
#   'make',
#   'u',
#   'life',
#   'easi',
#   'all'],
#  ['a',
#   'dns-sd',
#   'servic',
#   'registr',
#   'respond',
#   'mdn',
#   'queri',
#   'class',
#   'ani',
#   'respond',
#   'queri',
#   'class',
#   'in'],
#  ['pointemi', 'domain', 'feedli'],
#  ['provid',
#   'option',
#   'keep',
#   'keep-al',
#   'connect',
#   'background',
#   'creat',
#   'im'],
#  ['thi', 'import', 'featur', 'lack', 'wp8'],
#  ['goal', 'week', 'favourit', 'team'],
#  ['allow', 'enter', 'neg', 'valu'],
#  ['plea',
#   'look',
#   'musician',
#   'develop',
#   'use',
#   'midi',
#   'would',
#   'like',
#   'abl',
#   'devic',
#   'like',
#   'surfac',
#   'priorit',
#   'give',
#   'u',
#   'abil',
#   'innov',
#   'here'],
#  ['the',
#   'librari',
#   'use',
#   'wp',
#   'httpwebrequest',
#   'allow',
#   'pas',
#   'empti',
#   'header'],
#  ['can', 'least', 'give', 'option', 'make', 'cameracaptureui', 'fullscreen'],
#  ['chevronwp7______6______com', 'soon'],
#  ['for',
#   'cost',
#   'compani',
#   'would',
#   'receiv',
#   'two',
#   'unlock',
#   'windowsphon',
#   'devic',
#   'could',
#   'trade',
#   'upgrad'],
#  ['but',
#   'window',
#   'phone',
#   '8',
#   'emul',
#   'devic',
#   'nokia',
#   'lumia',
#   '920',
#   '2',
#   'problem',
#   'downloadprogress',
#   'properti',
#   'often',
#   'return',
#   '1.0',
#   'right',
#   'video',
#   'open'],
#  ['user', 'chang', 'languag', 'arab', 'flowdirect', 'rtl'],
#  ['thi',
#   'featur',
#   'ask',
#   'xaml',
#   'serial',
#   'featureset',
#   'pariti',
#   'wpf/system.xaml'],
#  ['i',
#   'dont',
#   'know',
#   'secur',
#   'norm',
#   'microsoft',
#   'allow',
#   'outsid',
#   'set',
#   'finguer',
#   'detect'],
#  ['i',
#   'experienc',
#   'ton',
#   'system',
#   'crash',
#   'recent',
#   'i',
#   'disabl',
#   'third-parti',
#   'loopback',
#   'driver',
#   'see',
#   'help',
#   'mean',
#   'i',
#   'lose',
#   'function'],
#  ['of',
#   'cours',
#   'would',
#   'even',
#   'better',
#   'make',
#   'xaml',
#   'use',
#   'typeconvert',
#   'addit',
#   'compatibility',
#   "'",
#   'sake',
#   'wpf'],
#  ['mani',
#   'app',
#   'cloud',
#   'servic',
#   'behind',
#   'cost',
#   'money',
#   'revenu',
#   'gener',
#   'two',
#   'week',
#   'situat'],
#  ['it', 'import', 'support', 'beta', 'window', 'phone', 'window'],
#  ['the',
#   'current',
#   'develop',
#   'ecosystem',
#   'windowsphon',
#   'app',
#   'focus',
#   'individu',
#   'develop',
#   'corpor',
#   'develop',
#   'account',
#   'typic',
#   'distribut',
#   'app',
#   'mass',
#   'via',
#   'marketplac'],
#  ['i',
#   'want',
#   'add',
#   'context',
#   'menu',
#   'option',
#   'instanc',
#   'zip',
#   'iso-fil'],
#  ['i',
#   'think',
#   'casual',
#   'genr',
#   'section',
#   'lot',
#   'app',
#   'fall',
#   'specif',
#   'section',
#   'alreadi',
#   'list'],
#  ['buffer',
#   'overrun',
#   'write',
#   'm_pdacl',
#   'writabl',
#   'size',
#   'pdacl-',
#   '>',
#   'acls',
#   'byte',
#   '8',
#   'byte',
#   'might',
#   'written'],
#  ['see', 'data', 'pile', 'follow', 'store'],
#  ['mediaelement_________http__________________cookie_________________________________________mediaelement___cookiecontain'],
#  ['for',
#   'one',
#   'product',
#   'need',
#   'support',
#   'nfc',
#   'card',
#   'reading/writ',
#   'exist',
#   'devic',
#   'sever',
#   'type',
#   'card',
#   'mifar',
#   'ul',
#   'ulc',
#   'calypso',
#   'desfir',
#   'mayb',
#   'even',
#   'more',
#   'i',
#   "'",
#   'v',
#   'read',
#   'wp8.1',
#   'function',
#   'ad',
#   'devic',
#   'specif',
#   'nfc',
#   'chipset',
#   'current',
#   'present',
#   'devic'],
#  ['if', 'author', 'avail', 'set', 'author', 'name', 'site', 'blog'],
#  ['unfortun',
#   'i',
#   'xbox',
#   'would',
#   'get',
#   'one',
#   'make',
#   'sen',
#   'it',
#   'free',
#   'app',
#   'i',
#   'realli',
#   'interest',
#   'spend',
#   'lot',
#   'money',
#   'develop',
#   'purpos'],
#  ['choos',
#   'login',
#   'automat',
#   'microsoft',
#   'account',
#   'save',
#   'phone',
#   'also',
#   'win8/rt',
#   'without',
#   'insert',
#   'login',
#   'password',
#   'again'],
#  ['in',
#   'pocket',
#   'set',
#   'i',
#   'seem',
#   'abil',
#   'set',
#   'pocket',
#   'usernam',
#   'password'],
#  ['a',
#   'locat',
#   'permiss',
#   'dialog',
#   'may',
#   'show',
#   'network',
#   'error',
#   'occur',
#   'unrel',
#   'part',
#   'code',
#   'exampl'],
#  ['textbox', 'indic', 'valid', 'result', 'thi', 'file', 'requir'],
#  ['delet', 'univers', 'window', 'platform'],
#  ['if', 'i', 'say', 'fatto', 'vocal', 'command', 'unrecogn'],
#  ['when',
#   'i',
#   'send',
#   'content',
#   'feedli',
#   'web',
#   'evernot',
#   'format',
#   'come',
#   'across',
#   'wonki',
#   'unclear'],
#  ['whi', 'use', 'winpho', 'style'],
#  ['and', 'wish', 'format', 'datetim', 'like', 'user', 'want', 'see', 'it'],
#  ['it', 'would', 'save', 'u', 'lot', 'time'],
#  ['at',
#   'moment',
#   'vsto',
#   'add-in',
#   'can',
#   'not',
#   'publish',
#   'window',
#   'store',
#   'offic',
#   'store'],
#  ['obvious',
#   'probabl',
#   'pin',
#   'requir',
#   'first',
#   'use/set',
#   'trust',
#   'nfc',
#   'capabl',
#   'wp',
#   'platform',
#   'never',
#   'fulli',
#   'realiz',
#   'simpl',
#   'tap',
#   'make',
#   'someth',
#   'happen',
#   'without',
#   'user',
#   'interfer'],
#  ['when', 'mediaplayerel', 'play', 'paus', 'video'],
#  ['i',
#   'would',
#   'like',
#   'better',
#   'access',
#   'lockscreen',
#   'i',
#   'complet',
#   'custom',
#   'includ',
#   'time',
#   'display',
#   'custom',
#   'content',
#   'like',
#   'photo',
#   'news',
#   'wallpap'],
#  ['it',
#   'would',
#   'nice',
#   'abl',
#   'render',
#   'xaml',
#   'visual',
#   'tree',
#   'perhap',
#   'background',
#   'task'],
#  ['plea', 'vote'],
#  ['i',
#   'would',
#   'like',
#   'abil',
#   'email',
#   'articl',
#   'gmail',
#   'post',
#   'googl',
#   'save',
#   'googl',
#   'drive',
#   'caus',
#   'googl',
#   'quit',
#   'enough',
#   'soul',
#   'yet'],
#  ['howev', 'downsid', 'would', 'place', 'widget', 'homescreen', 'folder'],
#  ['that', 'store', 'team', 'need', 'ingest', 'app', 'provid', 'store'],
#  ['current',
#   'three',
#   'addit',
#   'unnecessari',
#   'action',
#   'requir',
#   'show',
#   'download',
#   'histori',
#   'after',
#   'app',
#   'updat',
#   'select',
#   'notif',
#   'center',
#   '1',
#   'expand',
#   'menu',
#   'bar',
#   '2',
#   'select',
#   'download',
#   '3',
#   'swipe',
#   'histori'],
#  ['it', 'especi', 'wierd', 'sinc', 'sync', 'pictur', 'music'],
#  ['your',
#   'account',
#   'valid',
#   'symantec',
#   'you',
#   'can',
#   'not',
#   'submit',
#   'app',
#   'period',
#   'it',
#   'take',
#   '7',
#   '10',
#   'day',
#   'typic',
#   'open',
#   'account',
#   'set',
#   'make',
#   'sure',
#   'regist',
#   'inform',
#   'correct',
#   'when',
#   'modifi',
#   'account',
#   'inform',
#   'vet',
#   'trigger',
#   'automat'],
#  ['it',
#   'would',
#   'great',
#   'part',
#   'applic',
#   'iso',
#   'store',
#   'could',
#   'made',
#   'visibl',
#   'window',
#   'file',
#   'explor',
#   'phone',
#   'connect',
#   'usb',
#   'cabl'],
#  ['when',
#   'enter',
#   'address',
#   'detail',
#   'contact',
#   'address',
#   'detail',
#   'split',
#   'differ',
#   'field',
#   'anyway',
#   'one',
#   'would',
#   'expect',
#   'abl',
#   'access',
#   'individu',
#   'result',
#   'addresschoosertask',
#   'well'],
#  ['probabl',
#   'biggest',
#   'question',
#   'i',
#   'use',
#   'store',
#   'without',
#   'loo',
#   'abil',
#   'acquir',
#   'user',
#   'email',
#   'without',
#   'complic',
#   'process',
#   'end',
#   'user'],
#  ['you', 'group', 'friend', 'send', 'favorit', 'post', 'write', 'command'],
#  ['thi', 'contrari', 'doc', 'expect', 'behavior'],
#  ['it',
#   "'",
#   'seen',
#   'time',
#   'simpl',
#   'barrier',
#   'stop',
#   'peopl',
#   'activ',
#   'want',
#   'benefit',
#   'other'],
#  ['make', 'possibl', 'chang', 'iso', 'video', 'mode'],
#  ['advanc',
#   'audio',
#   'api',
#   'would',
#   'allow',
#   'develop',
#   'creat',
#   'music',
#   'applic',
#   'musician',
#   'etc'],
#  ['app',
#   'ca',
#   "n't",
#   'show',
#   'travel',
#   'rout',
#   'real',
#   'time',
#   'map',
#   'like',
#   'jog',
#   'app'],
#  ['abil',
#   'download',
#   'app',
#   'store',
#   'pc',
#   'instal',
#   'mobil',
#   'sd',
#   'card',
#   'support',
#   'like',
#   'lumia',
#   '920'],
#  ['mayb',
#   'default',
#   'way',
#   'look',
#   'slider',
#   'magnifi',
#   'user',
#   'tap',
#   'close',
#   'edg',
#   'list',
#   'signal',
#   'intent',
#   'useâ\x80¦',
#   'more'],
#  ['current', 'document', 'function', 'disabl'],
#  ['when',
#   'i',
#   "'m",
#   'access',
#   'api',
#   'i',
#   'get',
#   "1'200",
#   'fullchargecapacityinmilliwatthour',
#   "1'300",
#   'designcapacityinmilliwatthour'],
#  ['allow', 'close', 'task', 'long', 'press', 'right', 'button', 'phone'],
#  ['i',
#   'love',
#   'abl',
#   'share',
#   'short',
#   'text',
#   'messag',
#   'quickli',
#   'sharestatustask'],
#  ['my',
#   'suggest',
#   'add',
#   'option',
#   'pin',
#   'applic',
#   'use',
#   'futur',
#   'use',
#   'applic',
#   'open'],
#  ['the', 'issu', 'run', 'desktop', 'app', 'use', 'ui', 'access'],
#  ['if',
#   'phone',
#   'stolen',
#   'password',
#   'lock',
#   'still',
#   'possibl',
#   'take',
#   'photo',
#   'if',
#   'enabl'],
#  ['thi',
#   'real',
#   'problem',
#   'multipl',
#   'team',
#   'ship',
#   'app',
#   'need',
#   'share',
#   'master',
#   'account',
#   'name',
#   'password',
#   'lot',
#   'peopl',
#   'thu',
#   'remov',
#   'valu',
#   'use',
#   'ad',
#   'feder'],
#  ['map', 'here', 'drive', 'stop', 'work', '8.1', 'prev'],
#  ['i',
#   'saw',
#   'imageex',
#   "'",
#   'fade',
#   'anim',
#   'allow',
#   'develop',
#   'chang',
#   'durat',
#   'fix',
#   'one',
#   'second'],
#  ['kakaotalk',
#   'download',
#   'softwar',
#   'app',
#   'mobil',
#   'devic',
#   'allow',
#   'user',
#   'send',
#   'receiv',
#   'messag',
#   'includ',
#   'photo',
#   'video',
#   'contact',
#   'inform',
#   'one',
#   'one',
#   'basi',
#   'group',
#   'free'],
#  ['stuff', 'publish', 'eric_rulz'],
#  ['is', 'sort', 'bug', 'tracker', 'microsoft', 'softwar'],
#  ['more', 'detail', 'found', 'issu'],
#  ['a/b', 'test', 'crucial', 'quantit', 'market'],
#  ['but',
#   'phone',
#   'call',
#   'simul',
#   'systemmediatransportcontrol',
#   'paus',
#   'button',
#   'click',
#   'mediaplayer.systemmediatransportcontrols.buttonpress',
#   'event',
#   'phone',
#   'call',
#   'i',
#   'correctli',
#   'stop',
#   'player',
#   'chang',
#   'state'],
#  ['it', 'keep', 'hang', 'i', 'login'],
#  ['bingmapsdirectionstask'],
#  ['thi',
#   'properti',
#   'need',
#   'implement',
#   'mobil',
#   'well',
#   'enabl',
#   'true',
#   'univers',
#   'app',
#   'scenario'],
#  ['6', 'check', 'email', 'gmail', 'subject', 'brolen', 'well', 'p', '.'],
#  ['i',
#   'two',
#   'version',
#   'app',
#   'one',
#   'window',
#   'phone',
#   '8.1',
#   'v1.x.x.x',
#   'anoth',
#   'one',
#   'window',
#   '10',
#   'mobil',
#   'v2.x.x.x'],
#  ['that',
#   'made',
#   'document',
#   'viewing/edit',
#   'app',
#   'terribl',
#   'user',
#   'experi'],
#  ['howev',
#   'abl',
#   'tie',
#   'data',
#   'revenu',
#   'data',
#   'limit',
#   'transact',
#   'data',
#   'download',
#   'csv',
#   'payout',
#   'summari',
#   'page'],
#  ['plea', 'fix', 'anoy', 'issu'],
#  ['seem', 'issu', 'sd', 'card', 'wp', '8.1', 'preview'],
#  ['thing',
#   'like',
#   'minconnectioninterv',
#   'maxconnectioninterv',
#   'slavelat',
#   'connect',
#   'supervisori',
#   'timeout'],
#  ['instead', 'w10m', 'open', 'i', 'releas', 'finger'],
#  ['the', 'side', 'area', 'allow', 'includ', 'facebook', 'twitter', 'feed'],
#  ['i',
#   'know',
#   'tweak',
#   'alarm',
#   'volum',
#   'insid',
#   'build',
#   'simpli',
#   'can',
#   'not',
#   'cover',
#   'user',
#   'need',
#   'provid',
#   'slider'],
#  ['i',
#   'think',
#   'could',
#   'made',
#   'simpler',
#   'support',
#   'exampl',
#   'headerstyle-properti',
#   'pivot'],
#  ['nav', 'view', 'made', 'full', 'proof', 'solut', 'develop'],
#  ['and',
#   'type',
#   'glyphuri',
#   'v',
#   'xaml',
#   'editor',
#   'type',
#   'equal',
#   'sign',
#   'pop',
#   'opinion',
#   'menu',
#   'open',
#   'fonticon',
#   'wizard'],
#  ['thi',
#   'end',
#   'frustrat',
#   'alreadi',
#   'distress',
#   'develop',
#   'make',
#   'job',
#   'much',
#   'harder',
#   'support',
#   'oper',
#   'needlessli'],
#  ['thi',
#   'might',
#   'requir',
#   'process',
#   'part',
#   'microsoft',
#   'form',
#   'custom',
#   'server',
#   'process',
#   'incom',
#   'outgo',
#   'data',
#   'microsoft',
#   'could',
#   'add',
#   'addit',
#   'charg',
#   'app',
#   'take',
#   'advantag',
#   'featur',
#   'cover',
#   'cloud',
#   'computing/storag',
#   'cost'],
#  ['ad',
#   'may',
#   'encourag',
#   'develop',
#   'port',
#   'app',
#   'window',
#   'io',
#   'make',
#   'thing',
#   'familiar'],
#  ['when',
#   'app',
#   'get',
#   'built',
#   'gener',
#   'singl',
#   'packag',
#   'distribut',
#   'version',
#   'o',
#   'within',
#   'developer-set',
#   'version',
#   'limit'],
#  ['http',
#   ':',
#   '//aka.ms/storesupport',
#   'http',
#   ':',
#   '//1drv.ms/1pk2hvp',
#   'when',
#   'corpor',
#   'custom',
#   'tri',
#   'submit',
#   'app',
#   'error',
#   'messag',
#   'your',
#   'account',
#   'permiss',
#   'submit',
#   'app',
#   'store',
#   'display',
#   'can',
#   'not',
#   'submit',
#   'app'],
#  ['i',
#   'would',
#   'like',
#   'option',
#   'buy',
#   'app',
#   'game',
#   'send',
#   'friend',
#   'gift',
#   'like',
#   'i',
#   'steam'],
#  ['support',
#   'login',
#   'twitter',
#   'facebook',
#   'microsoft',
#   'yahoo',
#   'vk',
#   'account',
#   'etc',
#   'remov',
#   'googl',
#   'account',
#   'login',
#   'support'],
#  ['the',
#   'r',
#   'markup',
#   'feed',
#   'identifi',
#   'author',
#   'e.g',
#   'dc',
#   ':',
#   'creator',
#   'use',
#   'set',
#   'author',
#   'attribut',
#   'evernot',
#   'note'],
#  ['sinc',
#   'i',
#   'develop',
#   'applic',
#   'could',
#   'massiv',
#   'profit',
#   'api',
#   'allow',
#   'volum',
#   'control',
#   'etc',
#   'i',
#   'want',
#   'use',
#   'them'],
#  ['you',
#   'could',
#   'renam',
#   'window',
#   '10',
#   'mobil',
#   'window',
#   '10',
#   'watch',
#   'could',
#   'stop',
#   'make',
#   'lumia',
#   'mobil',
#   'phone',
#   'could',
#   'start',
#   'make',
#   'lumia',
#   'smartwatch',
#   'window',
#   '10',
#   'watch'],
#  ['obvious', 'free', 'sdk', 'good', 'start'],
#  ['plea',
#   'add',
#   'possibl',
#   'open',
#   'html',
#   'file',
#   'locat',
#   'folder',
#   'phone',
#   "'",
#   'memori'],
#  ['if',
#   'datatempl',
#   'x',
#   ':',
#   'datatype=models',
#   ':',
#   'localstatu',
#   'refer',
#   'poco',
#   'class',
#   'seper',
#   'project',
#   'xaml',
#   'compil'],
#  ['the',
#   'fact',
#   'go',
#   'c',
#   'exploit',
#   'key',
#   'resourc',
#   'dx',
#   'd2d',
#   'drawingsurfac',
#   'w8',
#   'wpf',
#   'wp8',
#   'not',
#   'accept'],
#  ['the',
#   'microsoft-windows-wmi-act',
#   'etw',
#   'provid',
#   'updat',
#   'event',
#   'new',
#   'field',
#   'window',
#   '10',
#   '1803',
#   'specif',
#   'event',
#   '11',
#   'may',
#   'one',
#   'version',
#   'field',
#   'event',
#   'updat'],
#  ['thi', 'featur', 'i', 'miss', 'android'],
#  ['it',
#   "'",
#   'nice',
#   'notif',
#   'news',
#   'exampl',
#   'abl',
#   'read',
#   'short',
#   'extract',
#   'go',
#   'experi',
#   'dynam',
#   'rich',
#   'notif',
#   'display',
#   'gestur',
#   'left',
#   'side',
#   'home',
#   'screen',
#   'from',
#   'edg',
#   'swipe',
#   'w8.1',
#   'app',
#   'run',
#   'make',
#   'lock',
#   'screen',
#   'customiz',
#   '5',
#   'app',
#   'make',
#   'icon',
#   'open',
#   'tap',
#   'instead',
#   'unrol',
#   'notif',
#   'center',
#   'form',
#   'top',
#   'i',
#   "'m",
#   'bit',
#   'surpris',
#   'action',
#   'center'],
#  ['a',
#   'sampl',
#   'project',
#   'use',
#   'hawaii',
#   'ocr',
#   'api',
#   'would',
#   'help',
#   'developers.also',
#   'need',
#   'help',
#   'use',
#   'imag',
#   'pre-process',
#   'techniqu',
#   'support',
#   'imag',
#   'process',
#   'librari',
#   'wp8',
#   'improv',
#   'ocr',
#   'accuraci'],
#  ['a',
#   'better',
#   'implement',
#   'might',
#   'expo',
#   'new',
#   'properti',
#   'method',
#   'medialibrari',
#   'provid',
#   'access',
#   'podcast',
#   'subscript',
#   'manag',
#   'episod',
#   'access',
#   'object'],
#  ['it', 'use', 'uwp', 'app', 'window', 'explor', 'realli', 'shame'],
#  ['in', 'short', 'could', 'add', 'someth', 'like', 'manifest-fil'],
#  ['not',
#   'benefit',
#   'microsoft',
#   'samsung',
#   'put',
#   'power',
#   'hand',
#   'user',
#   'develop',
#   'which',
#   'mani',
#   'mani',
#   'peopl'],
#  ['allow', 'overflow'],
#  ['æ', '\x95', 'htc', '7', 'pro'],
#  ['it',
#   'use',
#   'window',
#   '8',
#   'earli',
#   'window',
#   '10',
#   'version',
#   'appar',
#   'chang',
#   'ago'],
#  ['plea',
#   'implement',
#   'file',
#   'upload',
#   'api',
#   'internet',
#   'explor',
#   'upload',
#   'pdf',
#   'doc',
#   'from',
#   'offic',
#   'hub',
#   'imag',
#   'video'],
#  ['bloggers/author',
#   'want',
#   'claim',
#   'money',
#   'regist',
#   'rss-feed',
#   'bank',
#   'paypal-account',
# ...
#   "'",
#   'app',
#   'separ',
#   'nokia',
#   's',
#   'app',
#   'separ',
#   'on'],
#  ['i', 'handl', 'render', 'entir', 'interfac', 'myâ\x80¦', 'more'],
#  ['i',
#   "'d",
#   'like',
#   'attach',
#   'sampl',
#   'app',
#   'i',
#   'understand',
#   'of',
#   'cours',
#   'possibl'],
#  ['if',
#   'user',
#   'uninstal',
#   'trial',
#   'even',
#   'track',
#   'fact',
#   'prevent',
#   'start',
#   'new',
#   'trial',
#   'later'],
#  ['i', 'didnâ\x80\x99t', 'find', 'option'],
#  ['first',
#   'word',
#   'work',
#   'next',
#   'word',
#   'work',
#   'add',
#   'space',
#   'second',
#   'attempt',
#   'work'],
#  ['scenario',
#   'an',
#   'applic',
#   'save',
#   'differ',
#   'file',
#   'format',
#   'file',
#   'extens',
#   'exampl',
#   'choic',
#   'txt',
#   'file',
#   'save',
#   'excel',
#   'm',
#   'offic'],
#  ['swipe', 'titl', 'would', 'good', 'solut'],
#  ['i',
#   "'d",
#   'like',
#   'know',
#   'rank',
#   'app',
#   'countri',
#   'categori',
#   'app',
#   'store'],
#  ['current', 'scrollviewer', "'", 'content', 'overpan'],
#  ['ineffici',
#   'app',
#   'disallow',
#   'user',
#   'still',
#   'enabl',
#   'experienc',
#   'develop',
#   'flexibl',
#   'offer',
#   'app',
#   'legaci',
#   'protocol',
#   'ca',
#   "n't",
#   'convert',
#   'push',
#   'notif',
#   'system',
#   'among',
#   'user'],
#  ['connect', 'host', 'non-corpor', 'remot', 'wifi', 'network'],
#  ['we',
#   'frequent',
#   'need',
#   'autom',
#   'test',
#   'run',
#   'differ',
#   'test',
#   'user',
#   'test',
#   'workflow',
#   'etc'],
#  ['open',
#   'platform',
#   'make',
#   'phone',
#   'actual',
#   'work',
#   'project',
#   'phone',
#   'featur'],
#  ['the',
#   'site',
#   'faster',
#   'chrome',
#   'ie',
#   'still',
#   'fast',
#   'give',
#   'poor',
#   'user',
#   'experi',
#   'due',
#   'lack',
#   'perform'],
#  ['thi',
#   'problem',
#   'window',
#   '8.1',
#   'windowsphon',
#   '8.1',
#   'i',
#   'listview',
#   'group',
#   'item'],
#  ['i',
#   'understand',
#   'winappdriv',
#   'current',
#   'support',
#   'webview',
#   'therefor',
#   'support',
#   'context',
#   'switch',
#   'context',
#   'command',
#   'provid'],
#  ['say', 'i', '100', 'object', 'draw'],
#  ['googl',
#   'reader',
#   'allow',
#   'get',
#   'public',
#   'r',
#   'feed',
#   'category/label',
#   'use'],
#  ['if',
#   'push',
#   'button',
#   'start',
#   'camera',
#   'app',
#   'start',
#   'search',
#   'qr-code'],
#  ['m', 'make', 'advenc', 'config'],
#  ['a',
#   'share',
#   'key',
#   'chain',
#   'share',
#   'data',
#   'app',
#   'help',
#   'app',
#   'featur',
#   'like',
#   'sso'],
#  ['just', 'like', 'window', '6.5'],
#  ['a',
#   'perfect',
#   'use',
#   'case',
#   'would',
#   'turn',
#   'twitter/facebook/etc',
#   'notif',
#   'forward',
#   'email',
#   'address',
#   'instead',
#   'clog',
#   'inbox'],
#  ['if',
#   'fm',
#   'radio',
#   'api',
#   'brought',
#   'would',
#   'amaz',
#   'could',
#   'get',
#   'rd',
#   'support',
#   'well'],
#  ['bring', 'famou', 'mock', 'framework', 'uwp'],
#  ['the',
#   'issu',
#   'seem',
#   'somewher',
#   'windows.ui.xaml.dll',
#   '!',
#   'textblockviewhelpers',
#   ':',
#   ':adjustpositionbycharactercount'],
#  ['howev', 'built', 'method', 'save', 'writeablebitmap', 'png'],
#  ['detail', 'custom', 'thought', 'u'],
#  ['it',
#   'would',
#   'allow',
#   'app/develop',
#   'track',
#   'app',
#   'restart',
#   'importantli',
#   'would',
#   'allow',
#   'app',
#   'provid',
#   'better',
#   'experi',
#   'allow',
#   'user',
#   'continu',
#   'last',
#   'left',
#   'off',
#   '--',
#   'with',
#   'app',
#   'run',
#   'specif',
#   'posit',
#   'app'],
#  ['le', 'app', 'low', 'cloud', 'process', 'data', 'storag', 'le', 'revenu'],
#  ['it',
#   'look',
#   'like',
#   'bridg',
#   'can',
#   'not',
#   'remov',
#   'folder',
#   'clean',
#   'environ'],
#  ['plea', 'make', 'avail', 'a', 'also', 'make', 'zune', 'tile', 'live'],
#  ['i', 'set', 'background', 'fix', 'color', 'black', 'more'],
#  ['an',
#   'exampl',
#   'first',
#   'might',
#   'be',
#   'i____v',
#   'heard',
#   'wordament',
#   'good',
#   'so',
#   'more'],
#  ['better', 'support', 'podcast'],
#  ['let', "'", 'say', 'app', 'display', 'news', 'stori'],
#  ['add', 'integr', 'toodledo'],
#  ['i', 'like', 'instapap', 'option', 'clunki'],
#  ['use',
#   'categori',
#   'filter',
#   'see',
#   'exampl',
#   'profession',
#   'contact',
#   'profession',
#   'rendez-v'],
#  ['the', 'twitter'],
#  ['ideal', 'emailcomposetask', 'would', 'get', 'well'],
#  ['i',
#   'think',
#   'good',
#   '3th',
#   'app',
#   'access',
#   'list',
#   'instal',
#   'app',
#   'decid',
#   'unistal',
#   'freez',
#   'lock',
#   'etc'],
#  ['we',
#   'abl',
#   'download',
#   'previou',
#   'version',
#   'releas',
#   'version',
#   'window',
#   'sdk'],
#  ['in',
#   'io',
#   'andorid',
#   'option',
#   'like',
#   'allow',
#   'instal',
#   'apps',
#   ',',
#   'allow',
#   'camera',
#   'allow',
#   'screen',
#   'captu',
#   'etc'],
#  ['sometim', 'review', 'previou', 'version', 'app'],
#  ['i',
#   'websit',
#   'run',
#   'medium',
#   'wp8',
#   'without',
#   'need',
#   'cover',
#   'howev',
#   'medium',
#   'data',
#   'sourc',
#   'avail',
#   'youtub',
#   'need',
#   'custom',
#   'add',
#   'url',
#   'websit'],
#  ['you', 'can', 'not', 'submit', 'app', 'period'],
#  ['i', "'m", 'use', 'microsoft', 'exampl', 'found', 'here'],
#  ['if',
#   'use',
#   '3rd',
#   'parti',
#   'control',
#   'librari',
#   'control',
#   'librari',
#   'vendor',
#   'vote',
#   'thi'],
#  ['some',
#   'power',
#   'hungri',
#   'task',
#   'high',
#   'prioriti',
#   'run',
#   'soon',
#   'extern',
#   'power',
#   'avail',
#   'wait',
#   'hour',
#   'batteri',
#   'charg',
#   '90'],
#  ['when',
#   'program',
#   'pin',
#   'task',
#   'bar',
#   'would',
#   'great',
#   'sent',
#   'top',
#   'left',
#   'open',
#   'like',
#   'next',
#   'show',
#   'task',
#   'button'],
#  ['m',
#   'write',
#   'feedback',
#   'desktop',
#   'bridg',
#   'i',
#   'think',
#   'team',
#   'innov',
#   'better',
#   'job',
#   'commun',
#   'problem',
#   'window',
#   'store',
#   'team'],
#  ['music', 'continu', 'play', 'respond', 'notif'],
#  ['you',
#   'know',
#   'sure',
#   'one',
#   'develop',
#   'produc',
#   'great',
#   'softwar',
#   'like',
#   'googl',
#   'chrome',
#   'paint.net',
#   'mani',
#   'other'],
#  ['enabl', 'fm', 'scan', 'function', 'develop', 'api'],
#  ['feel', 'free', 'contact', 'info', 'requir'],
#  ['add',
#   'right',
#   'left',
#   'orient',
#   'text',
#   'page',
#   'support',
#   'window',
#   'phone',
#   'studio',
#   'app',
#   'websit'],
#  ['with',
#   'umdf',
#   '2.0',
#   'write',
#   'umdf',
#   'driver',
#   'use',
#   'c-style',
#   'syntax',
#   'call',
#   'mani',
#   'method',
#   'avail',
#   'kmdf',
#   'driver',
#   'but',
#   'limit',
#   'phone',
#   'maker',
#   'oem'],
#  ['it',
#   'would',
#   'nice',
#   'option',
#   'somewher',
#   'could',
#   'reboot',
#   'system',
#   'straight',
#   'bio',
#   'menu'],
#  ['have', 'export', 'adob', 'xd', 'file', 'could', 'translat', 'xaml'],
#  ['plea',
#   'make',
#   'possibl',
#   'go',
#   'feedly.com',
#   'make',
#   'possibl',
#   'download',
#   'updat',
#   'within',
#   'extens'],
#  ['tab',
#   'version',
#   'small',
#   'number',
#   'user',
#   'i',
#   'need',
#   'upload',
#   'new',
#   'univers',
#   'packag',
#   'phone',
#   'version',
#   'app'],
#  ['unleash', 'develop', 'power', 'store', 'go', 'win'],
#  ['i', 'develop', 'i', 'transfer', 'three', 'applic', 'apphub'],
#  ['now',
#   'nativ',
#   'develop',
#   'option',
#   'frustrat',
#   'one',
#   'ca',
#   "n't",
#   'debug',
#   'nativ',
#   'code',
#   'that',
#   "'",
#   'execut',
#   'devic',
#   'without',
#   'real',
#   'devic'],
#  ['in',
#   'stack',
#   'overflow',
#   'forum',
#   'option',
#   'add',
#   'multipl',
#   'tag',
#   'relat',
#   'question'],
#  ['we',
#   'need',
#   'way',
#   'save',
#   'document',
#   'gener',
#   'popul',
#   'within',
#   'app',
#   'pdf',
#   'xp'],
#  ['i', "'m", 'school', 'teacher'],
#  ['there',
#   'panel',
#   'uwp',
#   'someth',
#   'similar',
#   'like',
#   'wrapgrid',
#   'doesn____t',
#   'work',
#   'well',
#   'item',
#   'variabl',
#   'size'],
#  ['whi',
#   'i',
#   'implement',
#   'contactpick',
#   'make',
#   'user',
#   'choos',
#   'implement',
#   'live',
#   'sdk',
#   'forc',
#   'log',
#   'in',
#   'phone',
#   'alreadi',
#   'know'],
#  ['i',
#   'expect',
#   'notif',
#   'center',
#   'site',
#   'see',
#   'new',
#   'thing',
#   'happen',
#   'account',
#   'sinc',
#   'last',
#   'visit'],
#  ['although',
#   'intent',
#   'increas',
#   'thread',
#   'throughput',
#   'respect',
#   'focu',
#   'write',
#   'api',
#   "'",
#   'foremost',
#   'develop',
#   'friendli'],
#  ['i',
#   'later',
#   'found',
#   'origin',
#   'submiss',
#   'also',
#   'success',
#   'even',
#   'though',
#   'hung',
#   'two',
#   'duplic',
#   'submiss',
#   'process',
#   'certif',
#   'slightli',
#   'differ',
#   'alias'],
#  ['after',
#   'littl',
#   'while',
#   'develop',
#   'may',
#   'think',
#   'that',
#   'anyway',
#   'go',
#   'thru',
#   'what',
#   "'",
#   'point',
#   'spend',
#   'time',
#   'here'],
#  ['flattr',
#   'still',
#   'lift',
#   'mainli',
#   'due',
#   'lack',
#   'content',
#   'creator',
#   'will',
#   'regist',
#   'flatter'],
#  ['if',
#   'think',
#   'user',
#   'buy',
#   'window',
#   'phone',
#   '7',
#   'contract',
#   'misus',
#   'plea',
#   'left',
#   'unlock',
#   'phone',
#   'buy',
#   'window',
#   'phone',
#   '7',
#   'without',
#   'contract',
#   'factori',
#   'unlock',
#   '(',
#   'her',
#   'factori',
#   'unlock',
#   'mean',
#   'phone',
#   'accept',
#   'sim',
#   'if',
#   'think',
#   'unlock',
#   'window',
#   'phone',
#   '7',
#   'user',
#   'suffici',
#   'knowledg',
#   'mistak',
#   'corrupt/delet',
#   'system',
#   'file',
#   'in',
#   'case',
#   'wan',
#   'na',
#   'suggest',
#   'make',
#   'window',
#   'phone',
#   '7',
#   'fulli',
#   'unlock',
#   'option',
#   'mean',
#   'user',
#   'want',
#   'unlock',
#   'window',
#   'phone',
#   '7',
#   'he/sh',
#   'unlock',
#   'it'],
#  ['tutori',
#   'video',
#   'flash',
#   'convers',
#   'convert',
#   'mp4',
#   'flv',
#   '(',
#   'http',
#   ':',
#   '//www.kvisoft.com/tutorials/how-to-convert-mp4-to-flv.html',
#   'convert',
#   'avi',
#   'flv',
#   '(',
#   'http',
#   ':',
#   '//www.kvisoft.com/tutorials/avi-to-flv-conversion.html'],
#  ['today',
#   'x',
#   ':',
#   'defaultbindmod',
#   'attribut',
#   'defin',
#   'default',
#   'bind',
#   'mode',
#   'gener',
#   'compil',
#   'data',
#   'bind',
#   'creat',
#   'x',
#   ':',
#   'bind'],
#  ['http',
#   ':',
#   '//connect.microsoft.com/visualstudio/feedback/details/613932/windows-phone-7-visual-studio-generates-uncompilable-code-when-adding-an-image-to-a-resource-fil'],
#  ['addit',
#   'payment',
#   'option',
#   'paypal',
#   'ad',
#   'allow',
#   'peopl',
#   'own',
#   'visa',
#   'card',
#   'advanc',
#   'featur',
#   'regist',
#   'dev',
#   'center'],
#  ['ideal',
#   'i',
#   'would',
#   'like',
#   'see',
#   'graph',
#   'of',
#   'purchas',
#   'purchas',
#   'price',
#   'plot',
#   'time',
#   'would',
#   'allow',
#   'quickli',
#   'see',
#   'chang',
#   'rate',
#   'purchas',
#   'more'],
#  ['better',
#   'music',
#   'player',
#   'i',
#   'like',
#   'zune',
#   'interfac',
#   'xbox',
#   'music',
#   'interfac',
#   'i',
#   'would',
#   'like',
#   'custom',
#   'move',
#   'scroller',
#   'bar',
#   'tell',
#   'mani',
#   'minut',
#   'play',
#   'song',
#   'skip',
#   'music',
#   'favorit',
#   'part',
#   '6'],
#  ['add', 'system', 'tray', 'support', 'app', 'minimis', 'system', 'tray'],
#  ['thi', 'miss', 'featur', 'sinc', 'window', 'mobil'],
#  ['thi', 'make', 'problem', 'thing', 'like'],
#  ['while',
#   'http',
#   'proxi',
#   'function',
#   'lost',
#   'sinc',
#   'window',
#   'phone',
#   'now',
#   'uwp',
#   'set',
#   'http',
#   'proxy',
#   '(',
#   'ip+port',
#   ',',
#   'username+psw',
#   'connect',
#   'wifi',
#   'manual'],
#  ['unabl',
#   'prevent',
#   'auto',
#   'close',
#   'inputpan',
#   'creat',
#   'issu',
#   'due',
#   'possibl',
#   'bug',
#   'inputpan',
#   'uwp',
#   'target',
#   'version',
#   '16299',
#   'tablet'],
#  [],
#  ['we', 'choic'],
#  ['if',
#   'legal',
#   'issu',
#   'i',
#   'firmli',
#   'believ',
#   'need',
#   'implement',
#   'window',
#   'phone',
#   'store'],
#  ['pubcent',
#   'user',
#   'abl',
#   'decid',
#   'much',
#   'want',
#   'receiv',
#   'get',
#   'payment'],
#  ['zune', 'could', 'it', 'audibl', 'support', 'get', 'drop', 'wp7'],
#  ['user', 'report', '1-2', 'day', 'more'],
#  ['well', 'ie', 'also', 'search'],
#  ['can', 'plea', 'expo', 'visem', 'event', 'window', 'speech', 'sythesi'],
#  ['a',
#   'long',
#   'ca',
#   "n't",
#   'give',
#   'relev',
#   'search',
#   'result',
#   'keep',
#   'darn',
#   'thing',
#   'away',
#   'phone'],
#  ['now', 'i', 'know', 'work', 'i', 'want', 'make', 'knowledg', 'public'],
#  ['make', 'chrome', 'packag', 'app', 'feedli', 'plea'],
#  ['a',
#   'lot',
#   'small',
#   'time',
#   'develop',
#   'like',
#   'mean',
#   'use',
#   'microsoft',
#   'store',
#   'host',
#   'app'],
#  ['thi',
#   'notif',
#   'opinion',
#   'make',
#   'winpho',
#   'still',
#   'differ',
#   'o',
#   'android',
#   'io'],
#  ['thank', 'advanc'],
#  ['in',
#   'case',
#   'fire',
#   'mediaplayer.playbacksession.playbackstatechang',
#   'event',
#   'possibl',
#   'detect',
#   'whether',
#   'app',
#   'paus',
#   'user',
#   'system'],
#  ['i',
#   'great',
#   'idea',
#   'work',
#   'sinc',
#   'week',
#   'i',
#   'tri',
#   'implement',
#   'schedul',
#   'i',
#   'surpris',
#   'see',
#   'avail',
#   'window'],
#  ['possibl', 'translat', 'function', 'might', 'use'],
#  ['the',
#   'function',
#   'would',
#   'get',
#   'origin',
#   'text',
#   'expect',
#   'return',
#   'either',
#   'xaml',
#   'object',
#   'mayb',
#   'abstract',
#   'represent',
#   'color',
#   'text',
#   'handl',
#   'control'],
#  ['iron', 'would', 'truli', 'make', 'uwp', 'univers'],
#  ['mayb',
#   'normal',
#   'screen',
#   'timeout',
#   'would',
#   'appli',
#   'well',
#   'rather',
#   'lock',
#   'screen',
#   'timeout'],
#  ['2', 'univers', 'window', 'app', 'ca', "n't", 'never', 'will'],
#  ['a', 'app', 'seller', 'i', 'deal', 'dissatisfi', 'custom', 'ever', 'while'],
#  ['it',
#   "'d",
#   'fantast',
#   'could',
#   'possibl',
#   'access',
#   'data',
#   'convert',
#   'classic',
#   'app'],
#  ['plea', 'increas', 'limit', 'mayb', 'opt', 'in'],
#  ['the', 'uwp', 'scrollbar', 'white', 'invis', 'light', 'background'],
#  ['it',
#   'similar',
#   'like',
#   'issu',
#   'http',
#   ':',
#   '//www.dcfever.com/cameras/specification.php',
#   '?',
#   'id=1620'],
#  ['if',
#   'index',
#   'realli',
#   'broken',
#   'for',
#   'reason',
#   'start',
#   'happen',
#   'pc',
#   'uncommon',
#   'fail',
#   'pick',
#   'neighbor',
#   'file',
#   'confirm',
#   'use',
#   'default',
#   'photo',
#   'app',
#   'open',
#   'photo',
#   'folder',
#   'lot',
#   'photo',
#   'show',
#   'one',
#   'photo'],
#  ['at',
#   'moment',
#   'privat',
#   'and',
#   'inaccess',
#   'via',
#   'reflect',
#   'trust',
#   'level',
#   'make',
#   'uniqu',
#   'contact/appoint',
#   'identif',
#   'imposs'],
#  ['the', 'test.log', 'file', 'creat', 'again'],
#  ['we', 'see', 'page-rot', 'effect', 'set', 'page'],
#  ['when',
#   'i',
#   'tri',
#   'use',
#   'text',
#   'someon',
#   'o',
#   'keep',
#   'crash',
#   'restart'],
#  ['current', 'choos', 'safari', 'chrome', 'option'],
#  ['hello'],
#  ['here', 'more'],
#  ['now', 'i', 'must', 'search', 'star', 'war', 'imdb'],
#  ['on', 'android', 'devic', 'hard', 'add', 'new', 'feed', 'feedli'],
#  ['so',
#   'someth',
#   'like',
#   'peerfinder.alternateidentities',
#   '[',
#   '``',
#   'bluetooth',
#   ':',
#   'unpair'],
#  ['when',
#   'japanes',
#   'ime',
#   'on',
#   'insert',
#   'charact',
#   'winform',
#   'richtext',
#   'editor',
#   'm',
#   'word',
#   'appli',
#   'font',
#   'style',
#   'left',
#   'charact'],
#  ['a', 'lot', 'differ', 'app', 'need', 'wake', 'exact', 'time', 'someth'],
#  ['compil', 'use', 'cl', 'test.cpp', 'md', 'run', 'rs4'],
#  ['on',
#   'io',
#   'creat',
#   'twitter',
#   'aggreg',
#   'user',
#   'topic',
#   'shown',
#   'one',
#   'screen'],
#  ['improv',
#   'load',
#   'time',
#   'app',
#   'increas',
#   'load',
#   'time',
#   'wait',
#   '2',
#   'second',
#   'le'],
#  ['offer',
#   'way',
#   'log',
#   'even',
#   'feedly',
#   "'",
#   'registr',
#   'system',
#   'might',
#   'also',
#   'help'],
#  ['if', 'app', 'ever', 'iap', 'elig', 'transfer'],
#  ['we',
#   'provid',
#   'differ',
#   'version',
#   'client',
#   'applic',
#   'time',
#   'convert',
#   'app',
#   'store'],
#  ['splash',
#   'screen',
#   'app',
#   'make',
#   'consum',
#   'wait',
#   'actual',
#   'screen',
#   'load'],
#  ['take',
#   'look',
#   'jqueri',
#   'mobil',
#   'demo',
#   'http',
#   ':',
#   '//jquerymobile.com/test',
#   'wp7',
#   'see',
#   'i',
#   'mean'],
#  ['whenev',
#   'drag',
#   'control',
#   'one',
#   'treeview',
#   'anoth',
#   'treeview',
#   'throw',
#   'except'],
#  ['if',
#   'intend',
#   'call',
#   'window',
#   'crt',
#   'microsoft',
#   'vc',
#   'i',
#   'miss',
#   'realli',
#   'legal/appropri'],
#  ['and', '50', 'object', 'triangl', 'mesh', 'tm'],
#  ['provid',
#   'automaticali',
#   'calendar',
#   'e',
#   'mail',
#   'view',
#   'multi',
#   'task',
#   'screnn'],
#  ['in',
#   'ideal',
#   'world',
#   'i',
#   'abl',
#   'invok',
#   'task',
#   'option',
#   'send',
#   'somewher',
#   'el',
#   'continu',
#   'forget',
#   'it'],
#  ['we',
#   'can',
#   'not',
#   'read',
#   'or',
#   'even',
#   'see',
#   'mp4',
#   'file',
#   'sd',
#   'card'],
#  ['3',
#   'the',
#   'aforement',
#   'forum',
#   'post',
#   'suggest',
#   'use',
#   'remot',
#   'api',
#   'work',
#   'around'],
#  ['the', 'problem', 'alway', 'provid', 'latest', 'version', 'onli'],
#  ['the', 'r', 'section', 'seem', 'work', 'app', 'instal'],
#  ...]

# %% [markdown]
# ---
#
# ## Task 5: Kaggle Competition (10 marks)
#
# Head over to https://www.kaggle.com/t/1f90b74da0b7484da9647638e22d1068
# Use above classifier to predict the label for test_unseen.csv from competition page and upload the results to the leaderboard. The current baseline score is 0.36823. Make an improvement above the baseline. Please note that the evaluation metric for the competition is the f-score.
#
# Read competition page for more details.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Preparing submission for Kaggle
StudentID = "StudentID_Lastname" # Please add your student id and lastname
test_unseen = pd.read_csv("test_unseen.csv", names=['id', 'text'], header=0)

# Here Id is unique identifier assigned to each test sample ranging from test_0 till test_1699
# Expected is a list of prediction made by your classifier
sub = {"Id": [f"test_{i}" for i in range(len(test_unseen))],
       "Expected": []}

sub_df = pd.DataFrame(sub)
# The code below will generate a StudentID.csv on your drive on the left hand side in the explorer
# Please upload the file as a submission on the competition page
# You can index your submission StudentID_Lastname_index.csv, where index is your number of submission
sub_df.to_csv(f"{StudentID}.csv", sep=",", header=1, index=None)

# %% [markdown]
# Mention the approach that you have chosen briefly, and what is the mean average f-score that you have achieved? Did it improve above the chosen baseline model (0.36823)? Why or why not?

# %% [markdown]
# Edit this cell to write your answer below the line in no more than 500 words.
#
# ---
#
# > Delete this line and your write answer here
#
# ---
