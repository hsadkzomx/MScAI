# %%
fname1 = "societies1.txt"
fname2 = "societies2.txt"

# %%
dict_f1 = eval(open(fname1).read())
dict_f2 = eval(open(fname2).read())

# %%
def txt_to_dict(txt):
    dict_f = eval(open(txt).read())
    return dict_f

# %%
dict_f = txt_to_dict("societies1.txt")

# %%
import networkx as nx

def build_graph(dict_f):
    
    G = nx.Graph()
    
    for society in dict_f:
        for i in range(0, len(dict_f[society])-1):
            for j in range(i+1, len(dict_f[society])):
                G.add_edge(dict_f[society][i],dict_f[society][j],attr=society)
    
    print("Plot the graph:")
    nx.draw_networkx(G)
    
    return G

# %%
G = build_graph(dict_f1)
# Out:
# Plot the graph:

# %%
def find_path(G, start, end, cutoff=4):
    # find all paths which length <= 4
    paths = nx.all_simple_paths(G, source=start, target=end, cutoff=cutoff)
    
    if list(paths) == []:
        # if there's no path between the start node and end node
        print(f"======= No path between {start} and {end}! =======")
        
    else:
        paths = nx.all_simple_paths(G, source=start, target=end, cutoff=cutoff)
        print(f"""======= All the paths from {start} to {end} with the paths of length <= {cutoff} =======
        {list(paths)}""")
       
        # find the shortest path
        shortest_path = nx.shortest_path(G, "Dracula", "Pumpkin")
        print(f"\n======= The shortest path from {start} to {end} is {shortest_path}=======")

# %%
find_path(G, "Dracula", "Pumpkin", cutoff=5)
# Out:
# ======= All the paths from Dracula to Pumpkin with the paths of length <= 5 =======
#         [['Dracula', 'Witch', 'The Witcher', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'The Witcher', 'Squid Game Square', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Lilo', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Lilo', 'Squid Game Square', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Elon', 'The Fly', 'Cockroach', 'Pumpkin'], ['Dracula', 'Witch', 'Elon', 'Ronaldo', 'Cockroach', 'Pumpkin'], ['Dracula', 'Witch', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Elon', 'Lettuce', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Elon', 'King Kong', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Elon', 'Squid Game Square', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Pocahontas', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Pocahontas', 'Squid Game Square', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Squid Game Square', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Squid Game Square', 'Ronaldo', 'Cockroach', 'Pumpkin'], ['Dracula', 'Witch', 'Squid Game Square', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Squid Game Square', 'Lettuce', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Witch', 'Squid Game Square', 'King Kong', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Squid Game Triangle', 'Witch', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Squid Game Triangle', 'Witch', 'Squid Game Square', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Ghost', 'Witch', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Ghost', 'Witch', 'Squid Game Square', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Ghost', 'Winnie the Pooh', 'Gabriel', 'Cockroach', 'Pumpkin'], ['Dracula', 'Cinderella', 'Witch', 'Elon', 'Ronaldo', 'Pumpkin'], ['Dracula', 'Cinderella', 'Witch', 'Squid Game Square', 'Ronaldo', 'Pumpkin']]
#
# ======= The shortest path from Dracula to Pumpkin is ['Dracula', 'Witch', 'Elon', 'Ronaldo', 'Pumpkin']=======
